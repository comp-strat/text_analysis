# %% [markdown]
# # Get exemplary pages for schools exemplary of each topic
#
# - Author: Jaren Haber
# - Institution: UC Berkeley; Georgetown University
# - Date created: January 2021
# - Date last edited: January 2021
#
# Description: Use page counts to rank school pages and look at those with highest scores for a given topic. Start with lists of distinctive terms and distinctive school websites for each topic. Getting distinctive pages is essential for text extraction and stimulus generation for our follow-up survey experiment.

# %% [markdown]
# ## Initialize

# %%
#!pip install nltk
#import nltk; nltk.download('stopwords'); nltk.download('punkt')

# %%
# Import packages
import pandas as pd # For working with DataFrames
import gc # To accelerate loading pickle files
import os, datetime, re, sys

import numpy as np
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer # approximate but effective (and common) method of stemming words
ps = PorterStemmer()

# %%
# Load functions from data mgmt/tools directory:
cwd = os.getcwd()
root = str.replace(cwd, "text_analysis/filter_top_pages", "")
sys.path.insert(0, root + "data_management/tools")

# For displaying basic DF info, storing DFs for memory efficiency, and loading a filtered DF:
from df_tools import check_df, convert_df, load_filtered_df, replace_df_nulls

# For quickly loading & saving pickle files in Python:
from quickpickle import quickpickle_dump, quickpickle_load 

# For saving and loading text lists to/from file:
from textlist_file import write_list, load_list

# %%
# Set file paths
thisday = datetime.date.today().strftime("%m%d%y")

charters_path = root + "misc_data/charters_2015.pkl"
ex_urls_path = root + "text_analysis/topic_modeling/stm_example_urls_011220.csv"
topwords_paths = [fp for fp in os.listdir(root + "text_analysis/topic_modeling/") if fp.startswith("top_words")]

# %% [markdown]
# ## Load data

# %%
# Load data, keeping only relevant columns
df = load_filtered_df(
    charters_path, 
    ["WEBTEXT", "CMO_WEBTEXT", "URL", "SCH_NAME", "INQUIRY_COUNT", "INQUIRY_RATIO", 
     "NUMWORDS", "NUMPAGES", "NCESSCH", "SY_STATUS15"])
# Out:
# # rows and cols:  (10965, 10)
# # duplicates by NCESSCH: 0
#
# Columns and # missing cases (if any):
# URL: 3828 missing
# SCH_NAME: 8421 missing
# INQUIRY_COUNT
# INQUIRY_RATIO: 4103 missing
# NUMWORDS
# NUMPAGES
# NCESSCH
# SY_STATUS15: 3619 missing
# WEBTEXT
# CMO_WEBTEXT

# %%
# Sanity check: Detect duplicates
print(len(df["NCESSCH"])) # Number of values in NCESSCH column
print(len(df["NCESSCH"])-len(df.drop_duplicates(subset="NCESSCH"))) # Method 1 to detect number of duplicates
print(len(list(df["NCESSCH"]))-len(list(set(df["NCESSCH"])))) # Method 2 to detect number of duplicates
# Out:
# 10965
# 0
# 0

# %%
# Load file with exemplary schools for each key topic in STM
ex_urls_df = pd.read_csv(
    ex_urls_path, low_memory = False, header = 0, 
    usecols = ['TOPIC', 'NCESSCH', 'URL']).sort_values(by = 'TOPIC')
ex_urls_df
# Out:
#          NCESSCH  TOPIC                                        URL
# 81   80336001839      1                 http://www.swecollege.org/
# 27   61152013697      1                        https://emsofl.com/
# 34   61962006745      1               http://ktlcharterschool.com/
# 43   62380011518      1                        http://www.sscs.cc/
# 59   63474011464      1                           http://ogcs.org/
# ..           ...    ...                                        ...
# 83   80336006517     28                    http://uprepschool.org/
# 85   80441006638     28        http://www.salidadelsolacademy.org/
# 88  110003500253     28                          http://ccpcs.org/
# 38   62271010851     28           http://www.gertzresslerhigh.org/
# 41   62271013868     28  http://www.publicpolicycharterschool.org/
#
# [280 rows x 3 columns]

# %%
# Merge exemplary schools with their WEBTEXT from web-crawled charter school data
ex_urls_df = pd.merge(df[["WEBTEXT", "NCESSCH"]], ex_urls_df, how = "right", on = "NCESSCH")
ex_urls_df
# Out:
#                                                WEBTEXT       NCESSCH  TOPIC  \
# 0    [(http://www.swecollege.org/, False, 0, We are...  8.033600e+10      1
# 1    [(https://emsofl.com/college-prep/, False, 1, ...  6.115201e+10      1
# 2    [(http://ktlcharterschool.com/, False, 0, Cont...  6.196201e+10      1
# 3    [(http://www.sscs.cc/, False, 0, In The News.....  6.238001e+10      1
# 4    [(http://ogcs.org/, False, 0, In The News...\n...  6.347401e+10      1
# ..                                                 ...           ...    ...
# 275  [(http://uprepschool.org/campuses/arapahoe-str...  8.033601e+10     28
# 276  [(http://www.salidadelsolacademy.org/, False, ...  8.044101e+10     28
# 277  [(https://www.ccpcs.org/, False, 0, \r\tJavaSc...  1.100035e+11     28
# 278  [(https://www.gertzresslerhigh.org/, False, 0,...  6.227101e+10     28
# 279  [(https://www.publicpolicycharterschool.org/, ...  6.227101e+10     28
#
#                                            URL
# 0                   http://www.swecollege.org/
# 1                          https://emsofl.com/
# 2                 http://ktlcharterschool.com/
# 3                          http://www.sscs.cc/
# 4                             http://ogcs.org/
# ..                                         ...
# 275                    http://uprepschool.org/
# 276        http://www.salidadelsolacademy.org/
# 277                          http://ccpcs.org/
# 278           http://www.gertzresslerhigh.org/
# 279  http://www.publicpolicycharterschool.org/
#
# [280 rows x 4 columns]

# %%
# Read in distinctive words for each selected topic. 
# We have 4 metrics for distinctiveness: score, prob, frex, and lift
topwords_dfs = [pd.read_csv(
    root + "text_analysis/topic_modeling/" + fp, low_memory = False) 
                for fp in topwords_paths]

# Merge these DFs by row
topwords_df = pd.concat([
    df.rename(columns = {"Unnamed: 0":"TOPIC"}) 
    for df in topwords_dfs], axis=1)

topwords_df
# Out:
#     TOPIC     score.1      score.2      score.3        score.4   score.5  \
# 0       1       cours       credit       colleg        student      high
# 1       2      athlet         club      galleri      basketbal       ace
# 2       3  elementari       school        middl          river      high
# 3       4        like          get         said           love    realli
# 4       5      campus       imagin        click          enrol    suppli
# 5       6   discrimin          sex       disabl      complaint     color
# 6       7         art       scienc      student        project     learn
# 7       8     spambot   javascript       window        madison      html
# 8       9        kipp        edlio        email          sorri       los
# 9      10  blackboard      comment          fax           site    valley
# 10     11      austin          san       summit        antonio   weslaco
# 11     12     univers     bachelor      husband          teach     degre
# 12     13  montessori     children        learn        waldorf     child
# 13     14       grade          ago         read   kindergarten       day
# 14     15        worn      uniform        shirt           pant   lotteri
# 15     16      agenda        board        minut           meet  committe
# 16     17      colleg  scholarship  preparatori  schoolmesseng   sequoia
# 17     18     student       school        learn           educ   charter
# 18     19        prep      scholar       uplift          enrol    memphi
# 19     20       akron   youngstown     columbus        diploma    dayton
# 20     21     academi          nha     launchpa        heritag   detroit
# 21     22      potato      chicken         oven       sandwich      asap
# 22     23    district       servic      employe     expenditur    budget
# 23     24        loop         user      privaci         servic  warranti
# 24     25    enmienda      harmoni       pblica          ttulo      segn
# 25     26     classic        essay         text        grammar     write
# 26     27       shall      student       violat        suspens    harass
# 27     28         que      escuela          una      estudiant       por
#
#       score.6      score.7     score.8    score.9  ...      prob.41  \
# 0       onlin      gilbert       creek    graduat  ...       admiss
# 1      denver      varsiti       staff     parent  ...  powerschool
# 2         bay        haven       north    academi  ...         view
# 3        work         help        know       want  ...          ask
# 4    newslett       school      parent        pto  ...          bus
# 5     constel       school       marit       race  ...        pleas
# 6       music         stem        club       math  ...      present
# 7        file         pane       score  gradebook  ...         size
# 8      verifi         send      messag      angel  ...       street
# 9   directori       search     twitter    privaci  ...        close
# 10       idea    torkelson       vista   debricca  ...        grade
# 11   nashvill         educ       pivot    teacher  ...        studi
# 12     volunt        donat      legaci  communiti  ...   curriculum
# 13       week          mrs       event        jun  ...       summer
# 14    charter         wear        shoe      dress  ...        child
# 15     budget      charter     council   director  ...      account
# 16      cadet       senior        high    graduat  ...          aid
# 17     academ      teacher    standard      grade  ...         meet
# 18        oop       forgot     virtual     newark  ...        upcom
# 19       high       toledo      canton       life  ...    cleveland
# 20     volunt    launchpad  background    charter  ...      current
# 21      chees      emerson         ucp      fruit  ...       potato
# 22      youth       health        food        isd  ...       annual
# 23        use      infring      liabil     inform  ...       purpos
# 24        ley  impedimento         hps     seccin  ...          sam
# 25        war     knowledg  vocabulari      latin  ...        basic
# 26       must       absenc      parent      child  ...       safeti
# 27    nuestro        mundo    croatian  bulgarian  ...     filipino
#
#        prob.42     prob.43    prob.44     prob.45    prob.46   prob.47  \
# 0       scienc  transcript    contact    opportun     includ     avail
# 1       soccer       coach        ace    advisori  volleybal      meet
# 2        learn   technolog     servic     program     dragon   primari
# 3        thank       alway     friend        join       give      next
# 4      faculti     mission     welcom      vision     import       fax
# 5         usda      reserv      state       civil     sexual    orient
# 6      product        game      robot        find       well     build
# 7        chang        must        set       indic       term  descript
# 8       portal       staff     search      famili     parent    island
# 9      privaci        form     street    question      updat   support
# 10       skill         rio        day    frontier       blvd   develop
# 11        live     current      staff        name     member      move
# 12        live      legaci      appli  philosophi    teacher    center
# 13        date      welcom     second       thank    announc    spring
# 14        navi         top       palm       cloth     associ    servic
# 15       final       offic   newslett      execut      locat     north
# 16     collegi      reserv      organ      member     summer    junior
# 17     mission       teach   opportun       focus    environ   respons
# 18         now        type    program     teacher     follow    submit
# 19         one       stori      akron     program       path     choos
# 20        site     detroit     leader     privaci       link   complet
# 21       pizza         get       made     emerson       meet     today
# 22  profession        list      facil     contact    benefit    system
# 23    identifi     teacher       time     protect      chang     avail
# 24        pkwi         sus        por      seccin     scienc      need
# 25        time     describ     exampl    children      first     class
# 26      reason     princip      class       andor     report    harass
# 27       angel    romanian  bulgarian     bilingu    swedish    danish
#
#       prob.48   prob.49    prob.50
# 0      semest    advanc      elect
# 1      denver  transpar   director
# 2      career    magnet     height
# 3       pleas    import      stori
# 4       board   payment   question
# 5       child   request     receiv
# 6       field      time     health
# 7        list      edit   download
# 8     atlanta  subscrib      posit
# 9       login       inc       post
# 10     requir       get      child
# 11      excit   coordin       earn
# 12       gift       age      organ
# 13        jun       end       link
# 14      middl     power      grade
# 15       list       inc   procedur
# 16      visit    street       serv
# 17      excel    includ       serv
# 18       site    academ     provid
# 19     person    assist       work
# 20       oper      need      skill
# 21      event    period      lunch
# 22     physic   account      feder
# 23      cooki       web       link
# 24     materi   coordin  tecnologa
# 25      chang   concept     detail
# 26   determin     state    written
# 27  norwegian   finnish   croatian
#
# [28 rows x 204 columns]

# %% [markdown]
# ## Score pages by keywords

# %%
# Create list of punctuation
import string # for one method of eliminating punctuation
punctlist = list(string.punctuation) # assign list of common punctuation symbols
punctlist+=['*','•','©','–','–','``','’','“','”','...','»',"''",'..._...','--','×','|_','_','§','…','⎫'] # Add a few more punctuations also common in web text
punctlist.remove('-') ; punctlist.remove("'")
punctstr = "".join([char for char in list(set(punctlist))])
punctstr = re.sub(r'_--', '', punctstr)

unicode_list  = []
for i in range(1000,3000):
    unicode_list.append(chr(i))

stopword_list = list(set(stopwords.words('english')))

# %%
def clean_sentence(messy_string, 
                   unicodelist = unicode_list, 
                   punctuations = punctstr, 
                   stopwords = stopword_list): 
    """Removes numbers, stopwords, emails, URLs, unicode characters, hex characters, and punctuation from a sentence 
    separated by whitespaces. Returns a tokenized, stemmed, cleaned list of words from the sentence.
    
    Args: 
        messy_string (str): may include spaces and punctuation
        unicodelist (list of str): list of unicode symbols
        punctuations (str): string containing punctuation marks
        stopwords (list of str): list of stopwords
    Returns: 
        Cleaned & tokenized sentence, i.e. a list of cleaned, lower-case, one-word strings"""
    
    
    # remove newline characters and "|" characters
    sentence = messy_string.replace("|", " ").replace("\n", " ")
    
    #replace \\x, \\u, \\b, or - followed by any character or anything that ends with \u2605
    #then replace \\x, \\t and then get rid of whitespace
    sentence = re.sub(r"\\x.*|\\u.*|\\b.*|-|\u2605$", "", messy_string.replace(u"\xa0", u" ").replace(u"\\t", u" ").strip(" "))
    
    #get rid of hex character like \xa0\ adn a\x80
    sentence = re.sub(r'[^\x00-\x7f]',r'', sentence) #replace anything that starts with a hex character 
    
    #code that basically removes all elements that appear in the unicode_list (looks like r'u1000|u10001|')
    sentence = re.sub(r'|'.join(map(re.escape, unicodelist)), '', sentence) #removes unicode
    li_text = []
    
    for word in re.split('\s', sentence): #splits by space 
        if ((word not in stopwords) and (not word.isdigit()) and ("@" not in word)) : #gets rid of the numbers and emails
        
            #gets rid of urls 
            if ((not word.startswith(('http', 'https', 'www'))) and (not word.endswith(('.com', '.net', '.gov', '.org')))):
                if ((not word.startswith('//')) and not word.endswith(('.jpg', '.pdf', 'png', 'jpeg', 'php'))): 
                                        
                    word = re.sub(r'['+punctuations+']|am|pm', r'', word) #get rid of punctuation, and the words am and pm
                    word = ps.stem(word) #stem word
                    li_text.append(word)
                    
    sentence = ' '.join(li_text) #joins all words together
    sentence = sentence.strip() #remove beginning and ending white space in string
    return sentence

# %%
def score_page(txt, 
               keywords):
    '''
    Assign a score to a page based on the normalized count of keywords it contains.
    
    Args:
        txt (str): text of a web page
        terms (list of str): list of terms to look for in pages (e.g., distinctive words for a given topic)
    Returns:
        score (float, range 0-1): how much this page reflects these keywords
    '''
    
    txt = clean_sentence(txt) # clean sentence
    num_words = len(txt.split()) # split on whitespace to find the number of words
    
    total_count = 0
    for word in keywords: 
        count = len(re.findall(str(word) + str("\W"), txt))
        total_count += count
        
    # normalize by page length and take the log to avoid very small values
    if num_words == 0:
        score = 0
    else:
        score = np.log(total_count / num_words)
    
    return score

# %%
def get_top_pages(pagelist, 
                  keywords, 
                  n = 3, ):
    '''
    Get the n most representative pages in a list of website pages (pagelist) by counting frequency of key terms.
    
    Args:
        pagelist (list of list of str): list of pages, each page a quadruple: (URL, is_pdf, depth, text_str)
        n (int): number of pages to return
        keywords (list of str): list of keywords to look for in pages (e.g., distinctive words for a given topic)
    Returns:
        pagelist_selected (list of list of str): n most representative pages given topwords, each page a quadruple (as with input)
    '''
    
    if len(pagelist) <= n:
        # if less than or equal to N pages, no need to filter
        print("ERROR: Scoring failed. Only {} pages scraped for this school, minimum is {} to score.".
              format(str(len(pagelist)), str(n)))
        return pages
    else:
        scores_dict = {}
        
        for page in pagelist:
            page_text = page[3]
            score = score_page(page_text, keywords)
            scores_dict[page] = score
        pagelist_selected = sorted(scores_dict, key=scores_dict.get, reverse=True)[:n]
        
        return pagelist_selected

# %%
# Test out page scoring/ranking function
keywords = topwords_df.iloc[0,1:].tolist()
get_top_pages(ex_urls_df["WEBTEXT"].iloc[0], keywords = keywords)
# Out:
# <ipython-input-18-fe6ee105459d>:25: RuntimeWarning: divide by zero encountered in log
#   score = np.log(total_count / num_words)
# [('http://www.swecollege.org/creditandgrades.html',
#   'False',
#   '1',
#   'College prep courses earn five (5) credits per semester. Students enrolling in postsecondary classes shall receive both high school credit and college credit for courses successfully completed.  The college semester credit hours convert to high school semester credits. Grades received at the postsecondary institution will affect a student’s high school grade point average. The high school will be accountable for recording grades and credit based on the college transcript. The GPA and class rank will reflect grades received under this program. All grades for postsecondary courses are “weighted grades” for the purpose of determining GPA.   \nCredit and GPA will be computed using the following table: \nGrade Scale\xa0\nRegular and Modified Classes\nHonors, AP and College/ University Classes*\nA(90-100)\n4.0\n5.0\nB (80-89)\n3.0\n4.0\nC (70-79)\n2.0\n3.0\nD(60-69)\n0.0\n0.0\nF(0-59)\n0\n'),
#  ('http://www.swecollege.org/curriculum.html',
#   'False',
#   '1',
#   'In order to prepare students for postsecondary coursework, students are taught by highly qualified teachers. Additionally, teachers of H.S. English and H.S. Math are college/ university-approved adjunct professors.  All of the core classes fulfill college course prerequisites and the curriculum is aligned to the community college developmental education courses.  Our program scaffolds students’ matriculation into college beginning freshman year.  All freshman participate in AAA 109, a credit bearing college course that focuses on college success strategies.  As students progress with their coursework they participate in developmental education courses which are taught on our campus, comprised of our students and taught by our adjunct professors.  Once students have demonstrated competency, they are able to continue with college level course'),
#  ('http://www.swecollege.org/graduationrequirements.html',
#   'False',
#   '1',
#   '\nIn pursuit of our mission to ensure that all students have the opportunity to receive a high school diploma and an associate’s degree and/ or certificate or up to two years of college credit, Southwest Early College High School has established the following graduation requirements. Our graduation requirements are aligned with the Colorado Commission of Higher Education.\n                                    Southwest Early College High Schools offers 3 Diploma Programs:                                    Cum Laude: 20 high school credits + 30 or more college credit hours                                    Summa cum Laude: 20 high school credits + 30-49 or more college credit hours                                    Magna cum Laude: 20 high school credits + 50+ college credit hours or an Associate’s degree or certificate                                \nCollege Prep (High School) Program                                            \nRigorous high school level course work aligned to CCHE\nHighly qualified teachers\nPrepares students for college-level course work quickly and efficiently\nCore classes fulfill college course prerequisites\nDesigned to help students at all levels including those who are academically ahead, right on track or behind\nTracks with the community college system by offering course content similar to their pre-college-level courses:\n                                                    CCR092 = College Composition and Reading\n                                                    MAT050= Quantitative Literacy\n                                                    MAT055 = Algebraic Literacy\n                                                    HS English Transition course\n                                                    MAT Transition course\nCollege Program                                            \nCourses and grades are recorded both on SWEC’s high school transcript and on the college transcript from the institution providing the course.\nCollege/university-approved professors\nCollege BRIDGE students attend CCD college courses on the SWEC campus as part of SWEC’s normal school day in classes composed entirely of SWEC students.\nCollege SELECT students attend college courses at area institutions such as CCD and EGTC, integrating into the classrooms and campus life of those institutions learning side-by-side with other college students.\nGrades & Credits\nSuccessful completion of a course is equivalent to 1 unit (10 credits). In order to ensure that students are proficient with the course work, they must receive a C or higher to earn the credits.\n                                    A= 90- 100\n                                    B= 80- 89\n                                    C= 70- 79\n                                    F= 69 and below\nThe following criteria shall entitle a student to a Southwest Early College HS Diploma                                \nSuccessful completion of 24 units (240 credits) in the prescribed categories listed below.\nPortfolio completion of the requirements and goals as listed on a students’ Individual Career and Academic Plan (ICAP) and/ or Individualized Education Plan (IEP).\nDemonstration of College and Career Readiness in English and Math\nMenu of options\nEnglish\nMath\nACCUPLACER or CCPT\n80 or 101\n85 or CCPT PADI 80\nAmerican College Testing (ACT)\n18\n19\nACT WorkKeys- National Career Readiness Certificate\nBronze or higher\nBronze or higher\nAdvanced Placement (AP)\n3 or higher\n3 or higher\nArmed Services Vocational Aptitude Battery (ASVAB Exam)\n31\n31\nCompletion of remedial course\n(C) or higher ENG090, CCR092\n(C) or higher MAT050, MAT055\nCompletion of 100+ College Course\nENG121\nMAT107 or higher\nIndustry Certificate\nTABE test\nTABE test\nScholastic Aptitude Test (SAT)\n430\n460\n                                 General Course of Study\n English: 4 units (a unit is equivalent to a course) \n  Courses include at least two units that emphasize writing or  ...
