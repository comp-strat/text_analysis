# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import pickle

# %%
import seaborn as sns

# %%
from sklearn.decomposition import PCA

# %%
from sklearn.manifold import TSNE
import numpy as np
import gensim

wem_newpath = "../Charter-school-identities/data/wem_model_train250_nostem_unlapped_300d.txt"
model = gensim.models.KeyedVectors.load_word2vec_format(wem_newpath)

# %% [markdown]
# ## PCA followed by TSNE visualization of HDBSCAN Clustered WordVecs

# %% [markdown]
# The following uses PCA to reduce the dimensions of the 300k+ normalized word vecs which have 300 dimensions to 50. Then it selects the ~40K words which were clustered using HDBSCAN to be embedded using TSNE. TSNE requires data of at most ~50 dimensions and a few thousand inputs to run in reasonable amount of time.

# %%
word_vecs = model[model.vocab]
row_sums = np.linalg.norm(word_vecs, axis=1)
unit_vecs = word_vecs / row_sums[:, np.newaxis]

# %%
with open ('fullmodel_labels', 'rb') as fp:
    full_labels = pickle.load(fp)

# %%
words = np.array(list(model.vocab))[np.where(full_labels!=-1)[0]]

# %%
label_vecs = unit_vecs[np.where(full_labels!=-1)[0]]

# %%
pca = PCA(n_components = 50)
pca.fit(label_vecs)
transformed = pca.transform(label_vecs)

# %%
projection = TSNE(perplexity=50.0).fit_transform(label_vecs)
np.save('TSNE_approx',projection) # takes around 30 min

# %% [markdown]
# ## Results

# %%
projection = np.load('TSNE_approx.npy')

# %%
len(projection)

# %%
import random
sample_ind = random.sample(range(len(projection)), 1000) # sample 1000 inds of the labeled/clustered wordvecs

# %%
len(sample_ind)

# %%
# not really informative
color_palette = sns.color_palette(n_colors = len(set(labels)))
cluster_colors = np.array([color_palette[x] for x in full_labels if x>=0])[sample_ind]
plt.figure(figsize=(16, 16)) 
for i, coord in enumerate(projection[sample_ind]):
    plt.scatter(*coord, s=50, linewidth=0, c=cluster_colors[i], alpha=.5)
    #plt.annotate(np.array(words)[sample_ind][i], (coord[0], coord[1]))

# %%
dict_path = '/home/jovyan/work/Charter-school-identities/dicts/'
# load dicts/wordvecs
dict_list = []
word_vecs_list = []
core_list = []
core_word_list = []
word_list = []
dict_names = ['inquiry', 'discipline']
for name in dict_names:
    with open(dict_path+name+'.txt') as f: 
        new_dict = f.read().splitlines()
        word_vecs = []
        core = []
        core_word = []
        word = []
        for i, entry in enumerate(new_dict):
            try:
                word_vecs.append(model[entry])
                word.append(entry)
                if i < 30:
                    core.append(model[entry])
                    core_word.append(entry)
            except:
                pass
        dict_list.append(new_dict)
        word_vecs_list.append(word_vecs)
        core_list.append(core)
        core_word_list.append(core_word)
        word_list.append(word)

# %% [markdown]
# ## Dictionary Word Clusters

# %% [markdown]
# The following code checks which clusters(if any) the dictionary words were labeled. The discipline dictionary contained 5 words that were clustered while the inquiry dictionary contained none.

# %%
labels = dict(zip(list(model.vocab), full_labels))

# %%
inq_clusters = [labels[word] for word in word_list[0]]
dis_clusters = [labels[word] for word in word_list[1]]

# %%
set(dis_clusters)
# Out:
# {-1, 178, 266, 342, 389}

# %%
np.where(np.array(dis_clusters) == 266)
# Out:
# (array([194, 308]),)

# %%
np.where(np.array(dis_clusters) == 342)
# Out:
# (array([161]),)

# %%
np.where(np.array(dis_clusters) == 389)
# Out:
# (array([353]),)

# %%
np.array(word_list[1])[np.where(np.array(dis_clusters) == 266)]
# Out:
# array(['large_stains', 'strapless_tops'],
#       dtype='<U37')

# %%
word_clusters[266] # contains large_stains and strapless_tops
# Out:
# array(['navy_black', 'solid_in_color—red', 'pants_capris', 'solid_brown',
#        'skirts_or_jumpers', 'sleeveless_shirts', 'blue_socks',
#        'halter_tops', 'jumpers_and_shorts', 'y5-8', 'tan_brown',
#        'oxford_cloth', 'socks_tights', 'pants_navy', 'bdu',
#        'including_soles', 'skirts_shorts', 'knit_shirts', 'shoestrings',
#        'tights_or_socks', 'mini-skirts_minidresses', 'capri_slacks',
#        'plaid_skirts', 'plain_collared', 'backless_shoes', 'white_maroon',
#        'polo-style', 'v-neck_sweater', 'white_or_burgundy', 'white_beige',
#        'turtle_neck', 'dress_skirt', 'collars_or_polos',
#        'leggings_are_not_permitted', 'sweater_vests', 'pim_hooded',
#        'long-sleeve', 'nylons', 'button-down', 'black_slacks',
#        'socks_solid', 'white_tights', 'ankle_socks', 'teal_black',
#        'camisoles', 'twill_pants', 'earrings_and_other_body', 'tan_khaki',
#        'round_neck', 'button-up', 'skorts_shorts', 'tan_navy',
#        'mid-thigh_or_longer', 'button-up_collared', 'loafer_type',
#        'polo_dresses', 'burgundy_plaid', 'jean_material',
#        'sweater_material', 'skirt_skort', 'streaked', 'hosiery',
#        'khaki/tan', 'pants_khaki', 'leggings_and_tights', 'sweat_suits',
#        'cargo_and_casual', 'crop_tops', 'pullover_sweater',
#        'sweaters_cardigans', 'skorts_capris', 'polo_or_button-up',
#        'button-down_oxford', 'wheelies', 'khaki_beige', 'skull_caps',
#        'pullover_or_cardigan', 'pant_or_skirt', 'navy_tan',
#        'navy_or_burgundy', 'shirts_polo', 'crewneck_sweatshirt', 'anklets',
#        'docker', 'skirts_or_skorts', 'modest_length', 'striped_shirts',
#        'dark_socks', 'slacks_or_skirts', 'solid_burgundy',
#        'skirt_or_jumper', 'colored_jeans', 'gold_bottoms',
#        'black_polyester/cotton', 'pants_no_leggings', 'crew-neck_pullover',
#        'solid-colored_white', 'dockers_style', 'pastel_pink',
#        'worn_as_outer', 'present_a_sagging', 'drooping_appearance',
#        'mini-skirts', 'exposed_midriffs', 'burgundy_shoes', 'cloth_dress',
#        'short-shorts', 'saggy_pants', 'maroon_white', 'jumpers/dresses',
#        'colored_slacks', 'pants_slacks', 'pleated_front',
#        'sandals_or_open-toe', 'colored_dyed', 'denim/jean_material',
#        'oversized_baggy', 'pants/shorts/skirts_must', 'cardigan_in_solid',
#        'ash_grey', 'socks_solid-colored', 'leather_braided',
#        'sweaters_vests', 'shorts_are_not_permitted', 'lycra',
#        'shirts_that_have_collars', 'solid-colored_sweaters',
#        'sweatpants_are_not_permitted', 'slacks_khaki', 'large_stains',
#        'shorts_jeans', 'khaki-colored', 'jumpers_and_skorts',
#        'shorts_or_jumpers', 'tattoos_or_other_markings', 'pony_tails',
#        'uggs', 'rompers', 'cut-off_jeans', 'tan_slacks', 'pants_or_skirt',
#        'clothing_and_bare', 'red_not_cardinal/dark', 'red/maroon',
#        'burgundy_sweater', 'shirt_with_collar', 'blue_collared',
#        'skorts_dresses', 'spike_or_plat-formed', 'jerseys_tank',
#        'tops_halter-tops', 'laces_solid', 'off-the-shoulder_shirts',
#        'socks/tights/leggings_must', 'smooth_opaque', 'cable_knit',
#        'socks/tights_solid', 'conservative_pants', 'hair_curlers',
#        'bloused', 'leotards', 'sweatpants_leggings', 'burgundy_or_white',
#        'skorts_or_skirts', 'v-neck_sweaters', 'lights_or_electronics',
#        'turtle_necks', 'hooded_jackets', 'maroon_polo', 'high-tops',
#        'short-or', 'solid-color', 'shorts_sweat', 'dark_solid-colored',
#        'rat_tails', 'slacks/pants', 'mini_skirts', 'backless_strapless',
#        'distracting_earrings', 'dickies_style', 'fleece_sweatshirt',
#        'patterned_tights', 'absolutely_no_sweatpants', 'flat_rubber-soled',
#        'strapless_tops', 'khaki/beige', 'polo-type', 'capris_shorts',
#        'low-riding', 'tan_burgundy', 'long-sleeve_polo',
#        'shirts_turtlenecks', 'pants/capris_khaki',
#        'jumpers/skirts/skort_jumper', 'skirt_or_skort—khaki',
#        'sandal_or_athletic', 'clogs_crocs', 'knit_polo/golf',
#        'maroon_collared', 'blue_cardigan', 'shirts/blouses_solid',
#        'khakis_jeans', 'initials_recs', 'pull-on', 'halter-type_shirts',
#        'tights_★', 'athletic_t\xad-shirt', 'boys\xad', '\u200bnavy',
#        'see-through_or_sheer', 'short-sleeve_shirts', 'dresses/rompers',
#        'lycra_undergarments', 'low_riser', 'skirt/skort',
#        'firmly_at_the_waist', 'trousers_with_a_belt', 'knee-length_skirt',
#        'blouse_with_embroidered', 'shirt_with_ccse',
#        'elastic_at_the_ankles', 'capris_or_pants', 'pants/slacks', 'thong',
#        'evergreen_sweater', 'hoodless', 'camis', 'sweatshirts_fleece',
#        'ripped_ragged', 'even_if_logoed', 'boots_or_sneakers',
#        'jumpers_or_skorts', 'polo_or_button-down', 'denim_corduroy',
#        'low-heeled_low-soled', 'camisoles_or_sports', 'jeans_or_patched',
#        'jumpers_skorts', 'burgundy_khaki', 'dark_spandex',
#        'leggings_or_yoga', 'blue_2xl', 'pants/capris_navy',
#        'spike_or_plat-form', 'shoes_or_open-back', 'athletic_slicks',
#        'sweats_no_rips', 'skirts_khaki', 'mesh_polo', 'striped_shirt',
#        'jeans_cargo', 'pants_jumpers', 'tops_halter',
#        'vests_that_are_white', 'colored_tights', 'slippers_flip-flops',
#        'boots_flip-flops', 'long-sleeved_navy', 'blue_blouses/polo',
#        'sweaters_sweater', 'sleeve_polo', 'shorts/', 'capri-length',
#        'tan_black', 'burgundy_gray', 'navy_socks', 'maroon_or_navy',
#        'tops/dresses', 'skirt_jumper', 'leggings_sweat', 'sandals_crocs',
#        'zip-front', 'sweater/jacket', 'beige_khaki', 'thermals',
#        'navy/dark'],
#       dtype='<U431')

# %%
word_clusters[342] # contains 'hotel_pans'
# Out:
# array(['fax_202-690-7442', 'call_303-282-6437', '469-274-4876',
#        '623-478-2344_ext', 'calling_833-216-safe',
#        'becky.collier_thevanguardschool.com', '504-373-6269',
#        'call_300-1506', 'defamatory_material', 'call_464-0771',
#        'hotel_pans', 'appears_dazed', '1-888-722-1223_or_email',
#        '671-5470', 'carton_of_low-fat', '505-373-0053', '612-314-7603',
#        '612-314-7604'],
#       dtype='<U431')

# %%
word_clusters[389] # contains 'utilizable'
# Out:
# array(['post_navigation', 'constellationschools.com', 'priority=_name=',
#        ..., 'sportives', 'culturel', 'périscolaires'],
#       dtype='<U431')

# %%
word_clusters[178] #cluster containing the entry 'smoke_a_cigarette' from discipline
# Out:
# array(['hs_a.61/ms', 'smoke_a_cigarette', 'property_were_you_harassed',
#        'd.6', 'a.43-47//ms', 'a.48-52', 'a.63-71/ms', 'a.52-56', '65/ms',
#        'a.53/ms', 'a.54/ms', 'a.64/ms', 'a.73-75/ms', 'a.58-60', 'a.55/ms',
#        'a.107/ms', '98/ms', '99/ms', 'a.35-36/ms', 'a.34-36', 'a.61-62/ms',
#        'a.50-51', 'a.72/ms', 'a.103-105/ms', 'a.85-87', 'a.100-102/ms',
#        'a.82-84', 'a.106,108/ms', 'a.109-110/ms', 'a.91-92',
#        'a.112,111/ms', 'a.113-118/ms', 'a.95-100', 'a.122/ms', 'a.120/ms',
#        'a.113-117/ms', 'a.95-99', 'a.113/ms', 'a.123/ms', 'a.127-131//ms',
#        'a.109-113', 'd.3'],
#       dtype='<U431')

# %% [markdown]
# ## Examining Some Word Clusters From HDBSCAN by Hand

# %%
word_clusters = [np.array(list(model.vocab))[np.where(full_labels == x)[0]] for x in set(full_labels)]

# %%
word_clusters[4] #living locations?
# Out:
# array(['living_in_motels', 'emergency_or_transitional', 'hotels_trailer',
#        'parks_or_camping', 'adequate_accommodations',
#        'shelters_are_abandoned', 'hospitals_or_are_awaiting',
#        'accommodations_are_living', 'adequate_accommodation',
#        'abandoned_in_a_hospital', 'parks_or_campgrounds',
#        'shelters_or_are_abandoned', 'camping_grounds', 'motels_trailer'],
#       dtype='<U431')

# %%
word_clusters[5]
# Out:
# array(['x1440_x2160', 'x2880_x3600', 'x4320_x5040', 'x5760_x6480',
#        'x7200_x7920', 'x8640_qr', 'x0_x720', 'x9360_x10080',
#        'x10800_x11520', 'x12240_x12960', 'x13680_x14400', 'x15120_x15840'],
#       dtype='<U431')

# %%
word_clusters[6] #biology!
# Out:
# array(['brain_respiratory', 'functions_of_the_immune', 'digestive_bowel',
#        'bladder_neurological', 'circulatory_endocrine', 'function_bowel',
#        'function_neurological', 'function_circulatory', 'growth_bladder',
#        'function_respiratory', 'function_endocrine', 'function_digestive',
#        'reproductive_function'],
#       dtype='<U431')

# %%
word_clusters[9] # names
# Out:
# array(['matt_jenkins', 'cj_fox', 'stephanie_olson', 'ridgedale_athletics',
#        'ana_lopez', 'kari_rivers', 'lilith_werner', 'coumba_gueye',
#        'kristie_sweeney', 'andrea_fisher', 'sebastien_babolat',
#        'celine_dissel', 'baldomero_alvarez', 'fan_yang', 'zheng_wang',
#        'perla_rivera', 'colleen_mcintee', 'adeline_leborgne',
#        'kevin_carlino', 'abi_osthimer', 'debbie_harrington',
#        'jeannie_brooks', 'haoli_collings', 'tzu_shan_huang',
#        'alisa_kaczorowski', 'helen_blue-redner', 'wanda_aponte',
#        'rebecca_schneider', 'christa_braun', 'gregoire_kande',
#        'lorena_veresh', 'foz', 'yachin_lee', 'alyssa_dillard',
#        'sabrina_poirier', 'tyler_berthelsen', 'nan_nan', 'christellem',
#        'naxin_fan', 'karla_tarkington', 'april_wolcott'],
#       dtype='<U431')

# %%
word_clusters[10] # more names
# Out:
# array(['older_post', 'next_entries', 'newer_entries',
#        'apply_on_applitrack', 'tail-waggin_tutors', 'kelly_mcnerney',
#        'erin_ellinger', 'cherie_mcelroy', 'shaundria_wise', 'tanner_lynn',
#        'brad_fincher', 'lindsey_elders', 'lauriel_bristol',
#        'levi_molenhour', 'brittny_meredith', 'terrell_borum', 'amber_hurd',
#        'dave_funk', 'connor_kirk', 'kadence_niziurski',
#        'melissa_strohmeyer', 'timothy_merritt', 'sumeet_sidhu',
#        'nathan_maul', 'russell_cohoon', 'audrey_wiedemann',
#        'rebekah_lischwe', 'travis_hollowood', 'erica_leong', 'steve_doll',
#        'maegan_ruiz', 'chris_henkel', 'kat_mowczko'],
#       dtype='<U431')

# %%
word_clusters[11] #legal jargon
# Out:
# array(['limitation_of_liability', 'jurisdictions_do_not_allow',
#        'exclusion_of_certain', 'limitation_or_exclusion',
#        'warranties_these_exclusions', 'accordingly_some_of_the_foregoing',
#        'allow_the_limitation', 'exclusion_of_incidental',
#        'consequential_or_other_types',
#        'damages_so_some_of_the_above_limitations', 'incidental_damages',
#        'liability_for_consequential', 'consequential_or_incidental',
#        'limitations_on_implied', 'warranties_or_limitations',
#        'exclusion_or_limitation', 'warranties_or_the_exclusion',
#        'damages_so_the_limitations', 'states/jurisdictions_do_not_allow',
#        'exclusion_of_liability', 'damages_the_above_limitation'],
#       dtype='<U431')

# %%
word_clusters[12] # nonsense that should probably be cleaned
# Out:
# array(['finde_den', 'plan_er', 'stand_til', 'rigtige_kostume', 'med_en',
#        'masse_kvalitet', 'og_opfylde', 'kundernes_behov', 'tøj_muligheder',
#        'vi_sætter', 'en_ære', 'nødvendig_og', 'bør_være',
#        'tã¸j_muligheder', 'vi_sã¦tter', 'en_ã¦re', 'nã¸dvendig_og',
#        'bã¸r_vã¦re'],
#       dtype='<U431')

# %%
word_clusters[13] # drugs
# Out:
# array(['opiate_addiction', 'center_in_belton', 'benzo_addiction',
#        'ptsd_treatment', 'oxycodone_addiction', 'percocet_addiction',
#        'ocd_treatment', 'self-harm_treatment', 'dementia_treatment',
#        'painkiller_addiction'],
#       dtype='<U431')

# %%
word_clusters[14:] # rest of them
# Out:
# [array(['til_vores', 'dette_produkt', 'blev_tilføjet', 'katalog_søndag',
#         'katalog_torsdag', 'katalog_lørdag', 'katalog_onsdag',
#         'katalog_tirsdag', 'katalog_mandag', 'katalog_fredag'],
#        dtype='<U431'),
#  array(['ee_ben', 'oasdi_medicare', 'oasdi_reg', 'strs_certificated',
#         'benefits_cert', 'media_techno', 'cert_instructional',
#         'cert_other_general', 'classified_plant', 'supervision_and_adm',
#         'adm3502'],
#        dtype='<U431'),
#  array(['deductible_the_member', 'out-of-network_inpatient',
#         'outpatient_copay', 'diagnostic_outpatient',
#         'delivery_and_postpartum', 'deductible_diagnostic',
#         'procedures_in-network', 'out-of-network_diagnostic',
#         'complex_imaging', 'inpatient_maternity', 'freestanding_facility',
#         'inpatient_after_deductible', 'x-ray_covered',
#         'deductible_outpatient', 'inpatient_covered', 'transplants_covered'],
#        dtype='<U431'),
#  array(['including_asperger', 'deficiency_syndrome', 'major_depressive',
#         'borderline_personality', 'obsessive_compulsive',
#         'dystrophy_multiple', 'sclerosis_cancer', 'antisocial_personality',
#         'adults_with_attention-deficit/hyperactivity',
#         'substance-related_disorders', 'manic-depressive'],
#        dtype='<U431'),
#  array(['favor_none', 'apposed', 'seconded_by_vicki', 'seconded_by_norm',
#         'motioned_by_ellen', 'motioned_by_vicki', 'seconded_by_ellen',
#         'ellen_seconded', 'motioned_by_dave', 'motioned_by_jerry',
#         'motioned_by_rodney', 'vicki_motioned'],
#        dtype='<U431'),
#  array(['baldwin_carlisle', 'chambersburg_hanover', 'lansdale_norristown',
#         'phoenixville_plum', 'pottstown_state', 'west_mifflin',
#         'drexel_hill', 'wilkinsburg_allison', 'fullerton_horsham',
#         'levittown_willow', 'grove_allentown', 'altoona_bethlehem',
#         'chester_easton', 'erie_greensburg', 'harrisburg_hazleton',
#         'hermitage_johnstown', 'lancaster_lebanon', 'castle_philadelphia',
#         'sharon_wilkes-barre', 'williamsport_york', 'park_monroeville',
#         'mount_lebanon', 'murrysville_penn', 'mehlville_parkway'],
#        dtype='<U431'),
#  array(['74-1109750', 'main_720-531-3311', 'weather_303-387-7669',
#         'attendance_720-531-3313', '84-1412032', '27-3322474', '33-0913720',
#         'number_is_94-3370410', '20-5767786', '27-3364842', '45-5620286',
#         'number_20-2395640', '33-0', '46-4065855'],
#        dtype='<U431'),
#  array(['including_blindness', 'disabilities_orthopedic',
#         'disturbance_hearing', 'autism_and_traumatic', 'impairment_autism',
#         'autism_traumatic', 'impairment_traumatic',
#         'disturbance_an_orthopedic', 'orthopedic_handicapped',
#         'impairment_visual', 'speech/language_disability',
#         'deaf-blind_visually', 'impairment_intellectual',
#         'impairment_specific', 'injury_tbi', 'emotional_disturbances',
#         'injury_other_impairment', 'deaf/blindness',
#         'orthopedically_impaired'],
#        dtype='<U431'),
#  array(['bluesky_2007-08', 'bluesky_2011-12', 'bluesky_2009-10',
#         '2013-14.pdf', 'jlcs_and_cclcs', '2012-2013.pdf',
#         'peyton_quarterly', 'sy2014-15', 'sy2013-14', '2011-2012.pdf',
#         "sy'2013-2014"],
#        dtype='<U431'),
#  array(['incidental_special', 'exemplary_damages',
#         'purpose_and_non-infringement', 'companies_and_licensors',
#         'consequential_punitive', 'conditions_of_merchantability',
#         'damages_whatsoever', 'purpose_or_non-infringement',
#         'merchantability_and_fitness', 'merchantability_or_fitness',
#         'coloradoed_its_subsidiaries', 'merchantability_non-infringement'],
#        dtype='<U431'),
#  array(['choose_eaprep', 'choose_bcma', 'choose_spchs', 'choose_gaa',
#         'choose_civa', 'bca_is_different', 'choose_agamim', 'choose_acorn',
#         'choose_fdia', 'choose_goca', 'choose_a.m.e.', 'choose_newbridge',
#         'choose_sculptor', 'choose_pgpa', 'choose_hams', 'teach_at_ptaa',
#         'choose_pams', 'spart'],
#        dtype='<U431'),
#  array(['right_seth', 'pavlov_with_chess', 'grandmaster_sergey',
#         'fenton_and_lucas', 'karjakin_of_russia', 'fenton_rachel',
#         'prizant_danny', 'prizant_and_lucas', 'karjakin_holding',
#         'rachel_origami', 'dove_after_game', 'chess_super-fans',
#         'fenton_lucas', 'pavlov_rachel', 'prizant_and_danny',
#         'prizant_with_grandmaster'],
#        dtype='<U431'),
#  array(['iva_interest', 'directions_to_sporting', 'calendars/_family',
#         'pitching_in_on_fundraising', 'festivals_and_yearly', 'mcs_misc',
#         'canceled_and_rescheduled', 'sy18-19_recruitment',
#         'pto_news/upcoming', 'coordinating/helping_with_extracurricular',
#         'stargate_crc-fundraising'],
#        dtype='<U431'),
#  array(['parent_life/report', 'parent_info/report', 'truancies_unexcused',
#         'un-excused', 'constitute_excused', 'excused_unexcused',
#         'excessive_or_grossly', 'accrual_of_unexcused',
#         'attendance/_report', 'attendance-call'],
#        dtype='<U431'),
#  array(['payport_online', 'online_application/online', 'menus_mealtime',
#         'post_type=give', 'comment-4', 'comment-5', 'comment-6',
#         'ach_recurring', 'wahs_rent', 'payee_monthly', 'p=692', 'p=677',
#         'p=675'],
#        dtype='<U431'),
#  array(['placer_sacramento', 'alameda_contra', 'alameda_amador',
#         'calaveras_contra', 'obispo_santa', 'stanislaus_counties',
#         'mariposa_merced', 'solano_yolo', 'stanilsaus',
#         'stanislaus_sacramento', 'yolo_contra', 'sutter_yolo', 'sacremento'],
#        dtype='<U431'),
#  array(['formerly_the_chief', 'charge_of_the_mortgage', 'value_investors',
#         'club_valueinvestorsclub.com', 'co-founder_of_evercore',
#         'prior_to_csfb', 'prior_to_daiwa', 'head_of_the_mortgage',
#         'asset-backed_group', 'prudential_bache', 'eric_gonzales',
#         'putnam_investments'],
#        dtype='<U431'),
#  array(['oralaska_asian', 'pacific_islanderblack',
#         'readingmathematicsschooldistrictstate',
#         'readingmathematicssocial_studiesschooldistrictstate', 'studies0',
#         'readingmathematicsscienceschooldistrictstate',
#         'non-hispanichispanicmultiracialwhite_non-hispanicstudents',
#         'withdisabilitieseconomic_disadvantagelimited',
#         'studentsamerican_indian', 'average40'],
#        dtype='<U431'),
#  array(['anna_krivoy', 'lance_pickel', 'place_kaiden',
#         'bazdar_constellation', 'place_maeve', 'vana_constellation',
#         'amalia_watkins', 'place_gavyn', 'woo_constellation',
#         'parikh_constellation'],
#        dtype='<U431'),
#  array(['semester_8/13/18-12/14/18', 'registration_7/23/18-8/5/18',
#         'semester_1/14/19-5/17/19', 'registration_11/1/18-1/6/19',
#         'semester_8/27/18-12/14/18', 'registration_7/23/18-8/19/18',
#         'semester_1/28/19-5/17/19', 'registration_11/1/18-1/20/19',
#         'semester_9/10/18-12/14/18', 'registration_7/23/18-9/03/18',
#         'semester_2/11/19-5/18/19', 'registration_11/1/18-2/3/19',
#         '28-april', 'break-march'],
#        dtype='<U431'),
#  array(['matthew_morgan', 'heather_walter', 'mark_demers', 'cortney_labrie',
#         'kristi_heath', 'tracee_colgrove', 'elena_smith', 'danika_markey',
#         'image1', 'cathy_singer', 'august2013'],
#        dtype='<U431'),
#  array(['sional_development', '5-12_bell', 'faq_pricing', 'pyp_bell',
#         'myp_bell', '7-9_daily', 'prek_sample', 'final/midterm_exam',
#         'cmsa_tutoring', 'hr_delay', 'standard_mod', 'sites_tentative',
#         'testing_accomodations', 'girs_vaisty', 'danish_dialogue',
#         'sta_mca', '2017-2018\u200b_\u200bassessment', 'meadowood',
#         'mrs._tuma', 'jv/varsity_volleyball', 'hcp_baseball', 'mrs_hudgson',
#         'mrs._kruciak', 'mid-term_exam', 'interrupts_our_daily',
#         'scheduling_day/night', 'ms.coleman_class', 'horario/class',
#         'meal/work', 'aily'],
#        dtype='<U431'),
#  array(['ssas_summer', 'elementary_villa', 'kinder_galileo',
#         'whiskeytown_environmental', '2nd-5th_explorer', 'cacc_advanced',
#         'del_sol/camp', 'lael', 'ramah', 'pre-band', 'travis-sinclair',
#         'techknow', 'engineering_adventure'],
#        dtype='<U431'),
#  array(['respite/babysitter_training', 'brd_2017-2018', 'brd_2016-2017',
#         'brd_2015-2016', 'brd_2014-2015', 'brd_2013-2014', 'brd_2012-2013',
#         'brd_2011-2012', 'brd_2010-2011', 'brd_2009-2010', 'brd_2008-2009',
#         'brd_2007-2008', 'brd_2006-2007', 'brd_2005-2006', 'brd_2004-2005',
#         'brd_2003-2004', 'brd_2002-2003', 'brd_2001-2002', 'brd_2000-2001',
#         'brd_1999-2000', 'seac_2015-2016', 'seac_2014-2015',
#         'seac_2013-2014', 'seac_2012-2013', 'seac_2011-2012',
#         'seac_2010-2011', 'seac_2009-2010', 'seac_2008-2009',
#         'seac_2007-2008', 'seac_2006-2007', 'seac_2005-2006',
#         'seac_2004-2005', 'epa_compliance', 'ormation', 'bcps_handbook',
#         'lwcs_forms', 'ompliance', 'de_gouvernance', 'fequently_requested',
#         'endorsement_or_execution', 'rtant'],
#        dtype='<U431'),
#  array(['parental_written', 'cacfp_non-discrimination',
#         'lausd_non-discrimination', '•child_abuse', 'hhms_mission',
#         'diversity_inclusivity', 'racially_nondiscriminatory',
#         'ibo_mission', 'archimedean-athletics_mission', 'dhhs_mission',
#         'ndhs_mission', 'basketball_cautionary', 'glaw_non-discrimination',
#         'glasw_non-discrimination', 'fns_nondiscrimination',
#         'philosophy/mission', '06-30-17', '016-2017', 'iscrimination',
#         'post-election'],
#        dtype='<U431'),
#  array(['child_nutrition/family', 'homeless/social_services',
#         'teacher_selected/preferred/recommended', 'pp_media',
#         'usa.gov_parenting', 'rasd_tech', 'infohio_additional',
#         'maldef_scholarship', 'renewable_and_non', 'balances_of_spendable',
#         'deferred_outflow', 'immigration_refugee', 'buckle_up_employer',
#         'rly_childhood', 'isays_summit', 'main.html'],
#        dtype='<U431'),
#  array(['katherine_witt', 'elsol', 'suzanne_bowman', 'bfarris',
#         'pennacademy', 'socialtech', 'vonnchet_clark', 'smigela',
#         'fcma_admin', 'karrencolbert', 'liz_bowling', 'elif_dogru',
#         'ddillman', 'iqdesign', 'cody_pavlat', 'kuoregon', 'odyprep1',
#         'mark_weber', 'bhcsa_admin', 'logosweb', 'eagleartsacademy',
#         'wsacharter', 'far_hostagent', 'ldrummond', 'andy_mazur',
#         'far_lcrosland', 'netnom', 'keciah_bailey', 'far_hcade',
#         'far_cgoolsby', 'keiley_bradshaw'],
#        dtype='<U431'),
#  array(['group_identification', 'ethnicity_ethnic', 'religion_marital',
#         'color_ancestry', 'identification_age', 'ancestry_pregnancy',
#         'disability_marital', 'ancestry_physical', 'orientation_marital',
#         'status_marital', 'familial_status',
#         'breastfeeding_and_pregnancy-related', 'status_registered',
#         'perceived_disability', 'perceived_or_actual',
#         'ancestry_disability', 'ethnicity_gender/sex', 'ancestry_religion',
#         'pregnancy_familial', 'expression_sexual', 'status_genetic',
#         'disability_or_any_other_legally', 'religion_or_ancestry',
#         'religion_veteran', 'creed_pregnancy', 'identity_nationality',
#         'protected_classification', 'ancestry_marital',
#         'disability_genetic', 'physical_or_sensory',
#         'unlawful_consideration', 'identity_religion', 'color_ethnicity',
#         'creed_gender', 'identity_genetic', 'perceived_ancestry', 'admiss',
#         'ancestry_genetic', 'impairment_or_by_any_other_distinguishing',
#         'military_or_veteran', 'orientation_religion',
#         'transgender_identity', 'responsibilities_matriculation',
#         'disabilit', 'manner_reasonably', 'nonconformity',
#         'nationality_or_ethnic', 'amnesty', 'identity_ethnicity',
#         'heterosexuality_homosexuality', 'bisexuality',
#         'identity_pregnancy', 'stalking_harassment',
#         'gender_identity/expression', 'disability_pregnancy',
#         'martial/civil_union', 'rograms', 'creed_disability', 'admis',
#         'religion_nationality', 'disa', 'perceived_sex', 'race/color',
#         'sex/gender_sexual', 'non-conformity', 'expression_genetic',
#         'marital/civil_union', 'nationality_national',
#         'handicap/disability', 'gender/gender_identity',
#         'disability/handicap_or_marital/parental/family',
#         'sexual_stereotype', 'national/ethnic_origin',
#         'ability/disability_status', 'sex/gender_marital',
#         'religion_height', 'national_origi', 'disabil',
#         'status_affectional', 'status_spousal', 'sex/gender', 'reli',
#         'regard_to_race', 'disability/handicap', 'origin_ethnicity',
#         'ident', 'national_or_eth', 'disparagement_of_others',
#         'non-job_related', 'affectional', 'legally-protected',
#         'bases_of_race', 'handicap/disability_or_national', 'glbtq',
#         'childbirth_or_related', 'veteranstatus', 'gender-related_identity',
#         'religion/religious_beliefs', 'religion_immigration', 'alienage',
#         'militaty', 'affectional_or_sexual', 'weight_marital', 'civi',
#         'sexua', 'ethn', 'vetera', 'menta', 'sexualorientation', 'sexu',
#         'agnosticism', 'atheism', 'expression_pregnancy',
#         'identification_marital', 'pregna'],
#        dtype='<U431'),
#  array(['dvc_week', 'ghts', 'ctober', 'kwmcs_weekly', '\uf0b7_ptco',
#         'b._ptco', '5/18-newspaper', 'prep-prep', 'edusummit16', '8/16/2016'],
#        dtype='<U431'),
#  array(['eagleridgeacademy.org', 'fax_533-0974', 'waitlist_procedure',
#         'ihsnola.org', 'nvapatriots.us', 'prima_k', 'malions.org',
#         'academia.k12.de.us', 'cityartspcs.org', 'breach_of_the_condition',
#         'aplication', 'flacs_2018', 'application_18-19.docx',
#         'packet_sy18.pdf', 'timelin', 'harlemvillageacademies.org',
#         'eaglesnestflint.org'],
#        dtype='<U431'),
#  array(['spallino', 'amy_pinter', 'spallino_april', 'krejcir_february',
#         'spallino_october', 'krejcir_june', 'spallino_september',
#         'krejcir_april', 'spallino_august', 'spallino_july'],
#        dtype='<U431'),
#  array(['featured_posts', 'city_ccl', 'follow_wmaviation',
#         'follow_docassisi', 'dragon_football', 'follow_jphs',
#         'nws_sacramento', 'auto_publish', 'successcharter', 'follow_cfci',
#         'jces_pto', 'follow_wausauegl', 'follow_weareaisd',
#         'linkedin_myspace', 'llow_us', 'snapchat_texting', 'wiki_chat',
#         'biogs', 'myfoxphoenix', 'savesave_savesave', 'kik_oovoo', '\uf082',
#         'invictushigh', 'joycharter', 'mcspresidents'],
#        dtype='<U431'),
#  array(['kurdistan_iraq', 'erbil_kurdistan', 'michigan_u.s.a',
#         'choueifat_abu', 'choueifat_dubai', 'jeddah_saudi',
#         'sardam_international', 'duhok_kurdistan', 'fakhir_mergasori',
#         'sarwaran_international', 'kalar_international', 'kalar_kurdistan',
#         'soran_international', 'soran_kurdistan',
#         'suleimaniah_international', 'suleimaniah_kurdistan',
#         'zakho_international', 'zakho_kurdistan', 'flint_flint',
#         'saginaw_saginaw', 'choueifat_manama', 'choueifat_dream',
#         'city_erbil', 'choueifat_erbil', 'choueifat_sulaimani',
#         'choueifat_muscat', 'choueifat_doha', 'jeddah_private',
#         'choueifat_damascus', 'dhabi_khalifa', 'choueifat_ajman',
#         'choueifat_al', 'choueifat_ras', 'al_khaimah', 'choueifat_sharjah',
#         'choueifat_umm', 'al_quwain', 'minnesota_u.s.a', 'skybridge'],
#        dtype='<U431'),
#  array(['auto_created', 'marana_principal', 'posted_in_cra', 'amber_block',
#         'lucy_golden', 'siteadmin', 'lccps_spotlight', 'mma_announcements',
#         'mrs._spletzer', 'putney_travel', 'dr._posley', 'enviro_girls',
#         'hsa-belmont_reading', 'nclr_mariposa', 'august_gatesnotes',
#         'asha_moore', 'pogledajte_naš', 'whooo_reading', 'mrs._roosma',
#         'pyschologist', 'mbia'],
#        dtype='<U431'),
#  array(['tea_standings', 'tapr/aeis_information', 'pinemont_campus',
#         'southwest.pdf', '2016-2017_sde', 'src_definitions',
#         'nclb_northeast', '\ue092_ems', '\ue092_hs', 'tidwell/gano',
#         'tidwell/gano_federal', 'pinemont_federal', 'sarc.pdf', 'west.pdf',
#         '2009-10_annual', 'cde_spca'],
#        dtype='<U431'),
#  array(['gifted_/technology', '3rd_grade-2.pdf', 'kindergarten-2.pdf',
#         '1st_and_2nd.pdf', '2nd_grade-2.pdf', '4th_grade-2.pdf',
#         '5th_grade-1.pdf', 'dogon_and_bambara',
#         'gra\ufeff\ufeffd\ufeff\ufeffe', 'student/class'],
#        dtype='<U431'),
#  array(['parent_weekly-april', 'parent_weekly-september',
#         'parent_weekly-february', 'parent_weekly-october',
#         'parent_weekly-january', 'parent_weekly-may',
#         'parent_weekly-december', 'parent_weekly-november',
#         'parent_weekly-august', 'parent_weekly-march'],
#        dtype='<U431'),
#  array(['copyright_2002-2018', 'blackboard_inc.', '2009-2018_ala.',
#         'schoolwires_inc.', 'journey_schoo', '|512.805.3000_info',
#         'galileo_gifted', '2001-2018_aca', 'district_of_nekoosa',
#         'texasprep.u', 'hola_hoboken', 'rights_reserv', 'ep_website',
#         'rights_reser', 'rights_res', 'odyssey_academ', '2012-2018_aveson',
#         'texasprep.us', 'copyright_.all', 'website_conception',
#         'rights_rese', '293-4150_2018-06-06', 'woodward_academ', '·_wevs',
#         '2003-2017', 'agape_incorporated', 'keys_academie',
#         'divtag_templates', '©20', 'hawtho', 'partnershi', 'hawthor',
#         '2012-20', '2000-2018', 'osticket.com'],
#        dtype='<U431'),
#  array(['cec_network', 'mobile_navigation', 'hcg_injection', 'mrs._sprague',
#         'katelyn_haller', 'christine_lee', 'david_schmitt', 'heidi_pendroy',
#         'pa_vang', 'toua_lor', 'ezekiel_mua', 'ms._huhn', 'mrs._huhn',
#         'applicable_leases', 'visit_the_csaa', 'contains_phishing',
#         'contains_malware', 'mr._sixta', 'occupancy_certificate', 'ersham',
#         'ickens', 'enet'],
#        dtype='<U431'),
#  array(['transcript_and_document', 'space_membership',
#         'off-site_performance', 'parchment_transcript', 'chs_facility',
#         'assistance_from_eschoolview', 'url_is_invalid', 'laptop_repair',
#         'assistance_from_eschoolvie', 'personal/sick_day',
#         'url_is_forbidden', 'cnm_materials', 'sick/personal_leave',
#         'group_membersh', 'disability_accommodation', 'anscript',
#         'transcripts/records', 'transcri'],
#        dtype='<U431'),
#  array(['coalition_minutes.pdf', 'coalition_agenda.pdf', '2016-11-02',
#         '2014-10-14', '2017-04-03', '2017-11-13', '2015-12-13',
#         '2016-08-23_parent', '2013-03-27_parent', '2013-03-19_parent',
#         '2015-10-15', '2017-05-01', '2016-02-11', '2016-02-01',
#         '2014-11-11', '2017-10-16', '2017-09-18', '2017-07-24',
#         '2017-03-20', '2013-10-09', '2017-02-06', '2015-08-27',
#         '2017-08-21_parent', '2016-12-05_parent', '2016-10-04_parent',
#         '2016-03-03_parent', '2015-09-22_parent', '2014-09-23_parent',
#         '2014-03-12_parent', 'coalition_report.pdf', '2013-02-20_parent',
#         '2012-11-13_parent', 'coalition_bylaws.pdf', '2014-02-12'],
#        dtype='<U431'),
#  array(['landau_tatyana', 'parra_erick', 'krizman_ethan', 'wage_bryan',
#         'kathy_beasley', 'director_214-689-5545', 'borek', 'sophia_barrett',
#         'coord/teacher', 'teacher/ccr'],
#        dtype='<U431'),
#  array(['hernandez_carlos', 'matsubayashi_erik', 'wolfgram_kevin',
#         'harlow_misty', 'zuckerbraun_andrea', 'agcaoli_melvin',
#         'bilek_steven', 'gadh_anjana', 'hubbard_lisa', 'tokeshi_steven',
#         'deborah_barca', 'barrientez', 'avillarta_apagalv.org',
#         'traci_sullivan'],
#        dtype='<U431'),
#  array(['brick_by_brick', 'papalani_gelato', '19_bowling', 'yogurt_extreme',
#         'vernon_brunch', 'fearless_girl', 'laughing_planet', 'ppearls_club',
#         'mazzi_restaurant', 'lyco'],
#        dtype='<U431'),
#  array(['comparative_survey', 'security_schoolloop.com',
#         'parent/guardian_perception', 'teacher/staff_perception',
#         'stakeholder/community_perception', 'strand_measurement', '▪_oars',
#         '▪_caaspp', '▪_comparative', 'deyanira_casiano',
#         'clerk_214-637-6136', '§13.32_educational', 'science3',
#         'five-week_cycles', 'abbreviations_for_missing', 'map/mpg'],
#        dtype='<U431'),
#  array(['volleyall_open', 'volleyball-strength_and_conditioning',
#         'headwaters/upper', 'floor_resurfaced', 'pm_emks', 'pm_wsca',
#         'tiny_tots', 'bak_cafe', 'games_3:45-4:45', '4-5th_intramurals',
#         'sanded_level', 'dragila'],
#        dtype='<U431'),
#  array(['\u200b4th_grade', 'dismissal_at11:45', 'dismissal_at12:00',
#         'a.m.//2nd', 'a.m.//3rd', 'a.m.//5th', 'a.m.//\u200b6th', 'a.m.4th',
#         'a.m.5th', 'a.m.6th', 'room_173rd', 'room_115th', 'room_126th'],
#        dtype='<U431'),
#  array(['conlin_stacey', 'forslund_karla', 'gobin_robert', 'krumm_kendall',
#         'merritt_sandy', 'pell_chelsea', 'samuels_devlon',
#         "scott-o'neal_lindsay", 'sloffer_zachary', 'wagner_leslie',
#         'justus_mackintosh', 'kristen_welch', 'terry_griffis',
#         'ian_whiddett', 'byas', 'dorina', 'roni_burg', 'parscal'],
#        dtype='<U431'),
#  array(['export_to_xml', 'friday_7:55-3:05', 'all-day_repeats',
#         '2018-06-09t00:00:00-07:00', '2018-06-08t00:00:00-07:00',
#         'repeats_2018-06-01t12:50:00-07:00', '2018-06-21t00:00:00-07:00',
#         '2018-06-28t00:00:00-07:00', '2018-06-07t18:00:00-07:00', 'cjensen',
#         '2018-06-07t17:00:00-07:00', '2018-06-06t19:00:00-07:00',
#         'all-day_2018-06-07t00:00:00-07:00',
#         '2018-06-08t00:00:00-07:00_shs',
#         'all-day_2018-06-06t00:00:00-07:00',
#         '2018-06-07t00:00:00-07:00_shs', '2018-06-08t08:30:00-07:00',
#         '2018-06-01t13:40:00-07:00', '2017-11-27t00:00:00-08:00',
#         '2017-11-28t00:00:00-08:00', '2018-05-08t12:00:00-07:00',
#         '2017-09-29t00:00:00-07:00', '2019-06-06t17:00:00-07:00',
#         '2019-06-06t18:30:00-07:00', '2018-12-24t00:00:00-08:00',
#         '2019-01-05t00:00:00-08:00', '2018-05-24t18:30:00-07:00',
#         '2018-05-24t19:30:00-07:00', '2018-05-10t08:00:00-07:00',
#         '2018-05-11t08:00:00-07:00', '2018-05-11t12:00:00-07:00',
#         '2018-06-08t20:00:00-07:00', '2018-06-08t22:00:00-07:00',
#         '2018-05-16t13:00:00-07:00', '2018-05-15t12:52:00-07:00',
#         '2017-11-30t00:00:00-08:00', '2018-06-04t19:00:00-07:00',
#         '2018-06-04t20:00:00-07:00', 'all-day_2018-06-05t00:00:00-07:00',
#         '2018-06-06t00:00:00-07:00_shs', '2018-06-03t16:00:00-07:00',
#         '2018-06-03t22:00:00-07:00', '2017-08-23t00:00:00-07:00',
#         '2017-08-24t00:00:00-07:00', '2018-08-20t15:30:00-07:00',
#         '2018-08-20t16:30:00-07:00', '2018-05-21t16:30:00-07:00',
#         '2018-05-21t19:30:00-07:00', '2018-06-06t20:00:00-07:00',
#         '2018-06-08t12:00:00-07:00', '2018-06-0',
#         '2018-06-22t00:00:00-07:00', '2018-06-25t00:00:00-07:00',
#         '2018-06-26t00:00:00-07:00', '2018-06-27t00:00:00-07:00',
#         '2018-06-29t00:00:00-07:00', '2018-05-08t16:00:00-07:00',
#         '2017-09-30t00:00:00-07:00', '2018-05-10t12:00:00-07:00',
#         '2018-05-16t14:00:00-07:00', '2018-05-15t13:25:00-07:00',
#         '2017-12-01t00:00:00-08:00',
#         '2018-06-04t00:00:00-07:00_2018-06-05t00:00:00-07:00'],
#        dtype='<U431'),
#  array(['paycom', 'jmc_parent', 'schoolmax_family',
#         'alma_the_family/student', 'nm_sunshine', 'hive_parent',
#         'staff_csiu', 'csiu_parent', 'slds_parent', 'aeries_admin',
#         'jumprope_parent', 'powerschool_parentstudent',
#         'beyond_textbooks-parents', 'mms_administrator', 'alio_employee',
#         'set-up_guides', 'dasa_payment', 'de_aeris',
#         'aeries_parents/students', 'logging_on_at_myportal.gcu.edu',
#         'saisd_single-sign-on', 'echo-online_parent', 'nilc_tlc',
#         'fdoe_fsa', 'spsis', 'community.stargateschool.org'],
#        dtype='<U431'),
#  array(['/meaghan-chow', '/mrs-karen-golimowska', '/mrs.', '20vanloo',
#         '/jessica-appler', '/ms-murphy', '/valerie-grimm',
#         '/mrs-tates-first-grade', '/ms-michelle-lance', '/ms-murray',
#         '/amy', '/mary-sanford', '/christina-cameron-402',
#         '/mrs-gladdens-scholars', '/rosemary-hazle',
#         '/ms-haggertys-5th-grade', '/ben-graeff', '/erika-castillo',
#         '/7th-grade-math', '/megan-bovill', '/katherine-embry',
#         '/ms-beckford', '/rolanda-williams', '/dramabary',
#         '/cameron-kirk-schaffer', '/steve-swiech',
#         '/englewood-sky-academy-7th-8th-grade-math-mrs-fernandez',
#         '/sky-academy-englewood-hudachko-7th-8th-grade-science',
#         '/englewood-sky-academy-6th-grade-language-arts-mrs-jaques',
#         '/englewood-sky-academy-6th-grade-health-7th-grade-science-language-arts',
#         '/englewood-sky-academy-intensive-reading-health-teacher',
#         '/englewood-sky-academy-7th-8th-language-arts-mrs-melton',
#         '/brandon-sikkenga',
#         '/englewood-sky-academy-7th-8th-grade-social-studies',
#         '/englewood-sky-academy-6th-7th-grade-math-mrs-staley'],
#        dtype='<U431'),
#  array(['gymnastics_harp', 'swim_orchestra', 'photography_pilates',
#         'spiral_scouts', 'cooking_crafts', 'guys_on_the_go',
#         'speed_stackers', 'skiing_dance', 'drums_eco-maniacs',
#         'french_gaming', 'golf_guitar', 'robots_rockets', 'star_fleet',
#         'sewing_soccer', 'japanese_juggling', 'knitting_korean',
#         '4h_ballet', 'capoeira_chinese', 'band_rocks', 'ballet_baseball',
#         'r.e.c.e.s.s._rock', '4h_archery', 'campfire_capoeira',
#         'baseball_campfire', 'r.e.c.e.s.s._rocks', 'eco-maniacs_electronic',
#         'japanese_jedi', 'juggling_knitting', 'k-3_drums',
#         'breakdancing_campfire', 'sewing_skateboarding',
#         'brownies_campfire', 'dance_drums'],
#        dtype='<U431'),
#  array(['2017-18_user-friendly', 'fy_preliminary', 'expenditure_detail',
#         'fy2017_adopted', 'fy2016_adopted', 'fy2015_proposed',
#         'fy2015_adopted', 'fy17_adopted', 'fy2016_approved', 'fy13_adopted',
#         'nfps_adopted', 'jmphs_operating'],
#        dtype='<U431'),
#  array(['amao_parent', 'canine_search', 'ile', 'aer-district_cover',
#         'aer-elementary_cover', 'si-parent_option', 'tailor_your_cover',
#         'modern_illuminated', 'springwater_immunity', 'wipfli_engagement',
#         'chapultepec', 'espaillat'],
#        dtype='<U431'),
#  array(['jf_mobile', 'meal_menu.pdf', 'april/may/june_hot', 'lunch_supper',
#         'june_2018.pdf', 'adv_lunch', 'breakfast_menu.pdf', 'menu.pdf',
#         '2016-10_meal', 'lunch_menu.pdf', 'menu.pdf_title=', 'supper_menu',
#         'title=_neca', '2016-09_meal', 'tchs_meal', 'meal_menus.pdf',
#         'neca_2016-11', 'snack_menu.pdf', 'title=_cces', '2016-10_lunch',
#         '2016-11', '2016-11_meal', 'title=_ecals', 'title=_achieve',
#         'title=_jan', 'title=_december-meal-calendar', 'ecals_meal',
#         'iae_febuary', 'iae_january', 'iae_december', 'iae_november',
#         '2016-12', 'title=_milagro', 'title=_december-calendar-of-events',
#         'lunch-2017', 'breakfast-2017', 'title=_lca', 'title=_ccechs',
#         'glpa_september', 'title=_january-2017', 'title=_november-menu',
#         '2016-10', '2016-08', 'supper_menu.pdf', 'achieve_2017-01',
#         'achieve_2016-12', 'achieve_2016-09'],
#        dtype='<U431'),
#  array(['staff_webmail', 'wc_googleapps', 'upa_powerschools',
#         'upsm_powerschools', 'myedkey.org', 'edgenuity_educator',
#         'dearborn_admin', 'ohio_etpes', 'epicenter/parent_portal',
#         'mrs._pletzke', 'requires_mymec.org', 'first.lastname',
#         '//student.frontrowed.com/', 'osaic', 'lio'],
#        dtype='<U431'),
#  array(['sma-cpt_ese', 'walley', 'tina_ozee', 'maura_degracia',
#         'parent/board', 'email_mdegracia', 'stephanie_swick',
#         'summer_sewall-ssewall', 'kayla_hoag-khoag',
#         'channelsideacademy.com-elementary', 'name_meghann',
#         'conwell-mconwell_sunlakeacademy.org', 'sheila_pickern',
#         'linda_plante', 'family-school-community_outreach',
#         'frances_gutierrez', 'parent_liaison/homeless', 'school/career',
#         'parent/homeless'],
#        dtype='<U431'),
#  array(['zoo_snooze', 'qc_enrollment', 'celina_gifted', 'esources',
#         'cadet_permission', 'mandatory_tryout', '\u200bstaff_resources',
#         'budget/internal_financial', 'lunch_menu/order',
#         '\u200beducational_resources', 'view/download_athletic', 'ocuments',
#         'payroll/benefit/business_office', 'sample_foia'],
#        dtype='<U431'),
#  array(['jury_fund', 'supports_html5', 'youtub', 'watch_distinctions',
#         'tour_of_the_bwmc', 'ed-reflect', 'available_on_periscope', 'bbl_q',
#         'gradpoint_overview', 'introduces_mycroschool', 'creates_viral',
#         'camscanner', 'inventory.pdf'],
#        dtype='<U431'),
#  array(['shpa_pta', 'design_frogtummy', 'view_text-based', 'ms._mccormick',
#         'search_swa', '749-6000_x', 'teds_evaluation', 'design_by_desig',
#         'yment', 'cape_ptso', 'design_frogtumm', 'ms._corwin',
#         'welcome_to_our_re-designed', 'according_to_ncwit',
#         'designed_by_marchharemarketing.com', 'lanier_ffa',
#         'redesign_was_discussed', 'iva_pledgestar', 'lausd_echoices',
#         '//k2.summitps.org/', '//rainier.summitps.org', 'parenting.org'],
#        dtype='<U431'),
#  array(['se_92nd', 'avenue_clackamas', '97015-9648_telephone',
#         'fax_343-4500', '653-3996_653-1850', '653-3996',
#         '//cascadeheights.org/', 'telephon', 'telepho', '97015-9648'],
#        dtype='<U431'),
#  array(['powered_by_disqus', 'comment_wall', '//innocademy.com/blog/',
#         '//mosaicacademy.net/bode/', 'q=node/63', 'q=node/58',
#         'threats_verbal', 'q=node/64', 'q=node/48', 'p=59', 'p=46', 'p=24',
#         '0no', 'q=node/40', 'q=node/53', 'q=node/51', 'p=5279', 'p=5266',
#         'p=5245', 'p=5226', 'p=5211', 'questions/',
#         '//auldenver.org/_p=657', '//auldenver.org/_p=601',
#         '//tjca.teamcfa.school/school/thomas-jefferson-classical-academy'],
#        dtype='<U431'),
#  array(['responsive_web', 'schipul_web', 'boise_web', 'rstudio_web',
#         'adam_wright', 'ldd_web', 'animation_and_graphic', 'fashion_fabric',
#         'prostyle_web', 'fashion_interior', 'doubloon', 'wp-web'],
#        dtype='<U431'),
#  array(['cider_house', 'release_nslp', '\u200bon_social', 'mobius_new',
#         'currently_checked-out', 'makerfest', 'arts/yearbook-mass',
#         'media-communication', 'sproutbox', 'release/', 'bkreative'],
#        dtype='<U431'),
#  array(['sylmar_ca', 'glenoaks_boulevard', 'phone_837-6221', 'x1100_fax',
#         '837-6222', 'phone_356-2795', 'x2400_fax', '979-6579',
#         'phone_356-2591', 'x2500_fax', '356-2581', '979-65', '356-258'],
#        dtype='<U431'),
#  array(['n._grand', 'west_pico', 'w._talavi', 'w_ansley', 'campus_culver',
#         'w._augusta', 'n._occidental', 'west_sunrise', 'east_busch',
#         'onondaga_creek', 'e._shea', 'gail_harris', 'glenbrook',
#         'tierrasanta', 'kirby_ave', 'corner_of_baisley', 'gallivan',
#         'newlin', 'i-8_at_sports', 'address_jetway',
#         'intersection_of_isleta', 'valdora/armijo_armijo', 'east_valdora',
#         'southmore', 'located_at_galleria', 'pffs-university_e.',
#         'serramonte'],
#        dtype='<U431'),
#  array(['supplies_17-18', 'wildflower_open', 'additions_rfp',
#         'theodore_christensen', 'mrs_scott', 'sean_burgess', 'ms._salamon',
#         'managing_lice', 'anthony_marino', 'daisy_moreno',
#         'schoolmaster_web', 'ms._cechini', 'donna_orozco', 'dylan_ross',
#         'william_pulgarin', 'david_liebhauser', 'eman_saadi',
#         'erik_espinoza', 'nino_virtusio', 'said_cambray',
#         'sayra_santillanes', 'lucy_orozco', 'adriana_silva-alvarez',
#         'andrew_engel', 'diana_benavides', 'johhny_gonzalez',
#         'monica_arlette', 'paige_thompson', 'velez_marina',
#         'jacqueline_alvarado-melendez', 'dalia_coronel', 'dana_salg',
#         'radia_amari', 'zachary_cote', 'sonia_coronel',
#         'nwea_and_school-wide', 'jennifer_belmar', 'class_begins/breakfast',
#         'samuel_choi', 'sabrina_sherman', 'rules/expectations'],
#        dtype='<U431'),
#  array(['empty_sign-ups', 'holidays_and_fridays', 'isnm_office',
#         'may_28–31–school', 'tentative_gertz', 'eid_al-fitr-school',
#         'labor_day/school', 'wed-thurs', 'saturday-sunday', 'eid-ul-fitr'],
#        dtype='<U431'),
#  array(['english_9-p', 'english_10-p', 'spanish_3-p', 'spanish_4-p',
#         'biology-p', 'physics-p', 'french_3-p', 'spanish_1-p',
#         'spanish_2-p', 'art_1-p', 'art_2-p', 'rades_10-12', 'chemistry-p',
#         'french_1-p', 'french_2-p', 'american_literature-p',
#         'contemporary_literature-p', 'ap_spanish-p', 'ceramics_1-p',
#         'piano_1-p', 'economics-p', 'government-p', 'ap_government-p',
#         'french_4-p', 'anatomy/physiology-p', 'dance_2-p', 'dance_3-p',
#         'orchestra-p', 'choir-p', 'math_analysis-p', 'ap_statistics-p',
#         'arts/acting', 'photography-p', 'performance-p', 'workshop-p',
#         'arts-p'],
#        dtype='<U431'),
#  array(['linz', 'vidaurrazaga', 'mcparland', 'winbush', 'weide', 'halkyer',
#         'ellefsen', 'oliverio', 'recendez', 'jonee', 'mendy', 'figurski',
#         'lochan', 'furrow', 'afeefah', 'toscas', 'lindsea', 'kennya',
#         'lipford', 'zucchino', 'mardis', 'hillestad', 'white-henderson',
#         'marshall-becker', 'kasheta', 'akialis', 'jerez-givre'],
#        dtype='<U431'),
#  array(['phone_800-979-4436', 'line_303-802-4120', 'campus_561–412–4087',
#         'line_303-524-6354', 'phone_406-751-8101', 'line_303-524-6320',
#         'line_303-524-6350', 'line_303-524-6300', 'number_740-652-7220',
#         'campus_2nd-8th', 'number_214-904-3100', 'number_214-589-7902',
#         'number_214-643-4800', 'number_214-589-7651', 'number_214-583-6530',
#         'number_214-860-4440', 'number_214-860-4410', 'number_214-751-4100',
#         'number_214-589-2400', 'line_214-637-6136', '214-689-5501',
#         '406-751-8170', '951-545-0424', 'fax_952-545-0569', '501-683-3855',
#         '406-751-8110', '406-751-8145'],
#        dtype='<U431'),
#  array(['fcwcs_family', '2017-2018_student/parent',
#         '2017-2018_athletics-activities', 'ecrchs_parent-student',
#         '2017-18_student-parent', 'student-parent_athletic',
#         '4th–5th_grade', 'youth_fairstudent', 'download_scholar/family',
#         'olicies', 'cincinnati_parent-student', 'wayside_hr',
#         'sy2017-2018_student-parent', '2017-2018_leces', 'k–3rd_grade',
#         'pci_parent-student', 'scholar/parent', 'cdep_parent',
#         'preschool/elementary'],
#        dtype='<U431'),
#  array(['prs_agendas', 'bfc_agendas', 'ecc_agendas', 'epc_agendas',
#         'scc_agendas', 'spc_agendas', 'com_agendas', 'dac_agendas',
#         'exc_agendas', 'lrp_agendas', 'seac_agendas', 'sit_agendas',
#         'tec_agendas', 'brick_bulletins', 'dean_rubric',
#         'family/student_handbook', 'budget_assumptions',
#         'assumptions-tas-fy', 'guidebook_nas', 'vacancy_adds', 'apcab',
#         'hs2'],
#        dtype='<U431'),
#  array(['nas_aurora', 'chk_reg', 'feb_chk', 'jan_chk', 'oct_chk', 'dec_chk',
#         'nov_chk', 'aug_chk', 'sept_chk', 'july_chk'],
#        dtype='<U431'),
#  array(['whitney_hitchens', 'julie_leidel', 'test_coordinator/',
#         'nikki_densmore', 'roberta_denis', 'ila_kilgore',
#         'peims_214-698-4375', 'ursula_szabados', 'mary_deyo', 'karen_woodes'],
#        dtype='<U431'),
#  array(['flowery_branch', 'nw_atlanta', 'avenue_macon', 'tumbling_creek',
#         'street_blairsville', 'eastanollee_livestock', 'road_eastanollee',
#         'road_marietta', 'phone_770-509-5162', 'fax_770-509-5342',
#         'cobb_pkwy', 'nw_kennesaw'],
#        dtype='<U431'),
#  array(['melissa.laurento', 'craig.gibson', 'stacy.smith', 'rachel.murtagh',
#         'harold.smith', 'gabriel.soffer', 'sean.gensert', 'brian.tell',
#         'jordan.miller', 'laura.meyer'],
#        dtype='<U431'),
#  array(['call_524-4005', 'call_283-7908', 'call_524-4430', 'call_524-3642',
#         'call_524-3641', 'call_524-4410', 'call_524-3930', 'call_524-3910',
#         'call_283-0916', 'call_524-3734', 'call_524-3770', 'call_524-4420',
#         'call_524-3750', 'call_524-4141'],
#        dtype='<U431'),
#  array(['el_coordinador', 's._houston', 'para_información', 'sobre_sus',
#         'para_quejas', 'derechos_o_procedimientos', 'ix_charles',
#         'lambert_y/o', 'sección_ihsan', 'kara_a_la', 'siguiente_dirección',
#         'w._sam', 'houston_pkwy', 'tx_teléfono'],
#        dtype='<U431'),
#  array(['e-mail_mgomez', 'e-mail_kmortensen', 'e-mail_ecolon',
#         'e-mail_mching', 'e-mail_tbrickel', 'e-mail_ldatiz',
#         'e-mail_jgerndt', 'e-mail_sgaras', 'e-mail_lflores', 'e-mail_preda',
#         'e-mail_mfrancisco', 'e-mail_janaya', 'e-mail_vbotero'],
#        dtype='<U431'),
#  array(['msanchez_inglewood.k12.ca.us', 'bluegorilla', 'carlalee_boettger',
#         'elena_bilger', 'ed_mccray', 'lauren_locke', 'j.r._kerbel',
#         'ashley_velasquez', 'stephenie', 'noted_pediatrician'],
#        dtype='<U431'),
#  array(['gilbert_vaccination', 'fccs_public', 'non-dis', 'kgcs-lgc_public',
#         'orange-lgc_public', 'gsa_non-discrimination', 'non-d',
#         'nccef_public', 'non-discrimi', 'times2_allergy', 'boad_meeting',
#         'cheorkee_public', 'nondis', 'lead_abatement',
#         'board_meeting/agenda', 'nondi', 'nondiscrimi', 'nondiscrimina',
#         'nondiscr', '18-01-17', '17-11-15', '17-10-18', '17-09-17',
#         '17-08-16'],
#        dtype='<U431'),
#  array(['copy_to_google', 'kla_main', 'download_printable',
#         'printable_monthly', 'laconia_sports', '2018-19_ncs',
#         'dowload_2017-18', 'nvcs_2018-2019', 'mdcps_testing',
#         '2017-2018_arps', 'send_to_yahoo', 'subscribe_to_filtered',
#         'oss_assessment', '17-18_printable', 'cpcs_operational',
#         '18-19_innocademy', 'additions_or_updates', 'everest_phs',
#         '2017-18_hscs', 'sbcs_2017-18', 'acc_monthly', 'midvale_campus',
#         'gbcs_2017-2018', '2017-2018_year-at-a-glance', 'ecs_facilities',
#         'sy_2018-19.pdf', 'ns_elem', 'sblc_2017-2018', 'glasw_yearly',
#         'trict_events', 'doyle_classroom-based', 'ms._gangloff',
#         'pdas_appraisal', '2017-18_relc/rpsa', 'ʻalemanaka_kula',
#         '2018-2019_ccps', 'inno_18-19', '2015-16_a/b', 'jicms_monthly',
#         'monthly_ptec', 'gainesville_mycroschool', '2018-19_cta',
#         'scsd_yearly', '12:30-1', 'reacs_event', 'knos_mardi',
#         'gras_marching', 'arkansas_lhcs', '2018-2019_approved.pdf',
#         'alianza_activity', 'boardontrack_recommended', 'detailed_ism',
#         'sessment', '\u200b2018-19', '2014/15', 'msjc_2016-2017',
#         'mvc_2016-2017', '8.33—classified_personnel',
#         '3.29—licensed_personnel', 'tas-wahs', '2017-18_nwechs',
#         'toplan_the_annual', '12:15-12:30'],
#        dtype='<U431'),
#  array(['subscribe_me_to_your_mailing', 'faculty_favorites', 'walton_wish',
#         'mfcs_wish', 'x-1', 'u-3', 'v-1', 'v-3', 'w-1', 'u-1', 'v-2', 'v-4',
#         'x-2', 'x-5', '1/8', 'u_5th.doc', 'x_words.doc', 'x-4', 'u-4',
#         'z-1', 'z-2', 'z-3', 'list_u-2', 'y-1', 'y-2', 'y-3', 'y-4', 'v-5',
#         'z-4', 'directory/carpool'],
#        dtype='<U431'),
#  array(['jun_0000', 'apr_0000', 'feb_0000', 'dec_0000', 'feb_gmt',
#         'jun_gmt', 'sparknotes', 'apr_gmt', 'aug_0000', 'sep_0000',
#         'aug_gmt', 'oct_gmt', 'oct_0000', 'sep_gmt', 'jan_gmt', 'mar_gmt',
#         'yat', 'mar_est', 'nov_gmt', 'mar_gm', 'aug_0700', 'dec_gmt'],
#        dtype='<U431'),
#  array(['rp_media', 'helix_wellness', 'gould_educational', 'hock_media',
#         'hca_innovation', 'ode-lau_resource', 'lau_resource',
#         'gregory-lincoln_education', 'neff_early', 'nva_counseling',
#         'e-institute_of_metro', 'avm_media', 'rimes_early', '—pew_research',
#         'madison_kohl', 'compact/vantage_career', 'victims_of_torture',
#         'wellness/_fitness', 'olivencia'],
#        dtype='<U431'),
#  array(['pkwy_ramsey', 'bloomington_ave.', 'street_richfield',
#         's._bloomington', 'office_314-7600', 'fax_426-6020', 'fax_314-7609',
#         'office_426-6000', '952-426-6000', 'ne_otsego', '314-7609',
#         '314-7600_fax', 'kalland_ave', 'kalland_avenue',
#         'bloomington_campus\u200b', 'richfield_campus\u200b',
#         'west_76\u200bth\u200b', 'drive_woodbury'],
#        dtype='<U431'),
#  array(['cecilia_‘', 'read_tania', 'read_marquin', 'read_ignacio',
#         'read_myreon', 'read_venicio', 'read_lillith', 'read_ismael',
#         'read_theo', 'read_dametri', 'read_janae', 'read_shakota',
#         'aztec_creation', 'iusd_promise', '5th_–art', '➦'],
#        dtype='<U431'),
#  array(['//m.signupgenius.com/', 'northpoint_construction', 'rudy_bbq',
#         'peque', 'support_dyrsdc', 'janeen_comenote', 'visitng', 'adient',
#         'carrere', 'choosin'],
#        dtype='<U431'),
#  array(['subscribe_to_aces', 'archived_champion', 'item_homepage',
#         'credo_moves', 'aut_2-3', 'wla_latest', 'dvs_breaking',
#         'everest_breaking', 'hs_knights', 'kfxv-tv_fox', 'ms_knights',
#         'es_knights', 'physical_education/swimming', 'latest_eka',
#         'omi_sporting', 'futures_knights', 'times2_daily', 'latest_cosa',
#         'magazines_and_broadcast', 'source_chalkbeat', 'minborg',
#         'signup_for_ota', 'portola_counseling', 'susanville_counseling',
#         'source_wnyc', 'source_politico.com', 'wgn', 'finalfinal.pdf',
#         'beeline', 'wmpccs_ohana', 'january_kera', 'patti_klevorn',
#         'bangor_daily', 'featured_on_fox6', 'network_fnn', 'brisbin_akers',
#         'source_cbs', 'march_2016\ufeff', 'rivermill-academy', 'clips_2015',
#         'updates_from_the_seaborg', 'annou', 'no.5', 'may14', 'final3.pdf',
#         'photos_of_walkabout', 'kktv', '05-22-2018', 'kim_kozlowski',
#         'atest', 'sept_final.pdf', 'greeting_from_the_junto', '11-21_kg',
#         '11-6_kg', '10-18_kg', 'aired_on_the_abc', 'publicatio',
#         'jan.19-22', 'ured', 'ecent', '9-05-17', 'channel3', 'april24',
#         'may15', 'may1', 'feb12', 'final5.pdf', 'dogo'],
#        dtype='<U431'),
#  array(['problem-and-solution', 'comparison-and-contrast', '268–275',
#         '836–843', '112–119', 'comparison‐and‐contrast', '416–423',
#         '658–665', '844–851', '322–323'],
#        dtype='<U431'),
#  array(['cancellation_will_be_communicated', '3/23_classes',
#         'following_dates:3/16', 'following_dates:3/13', '4/17_4/24',
#         'instructor_daniel', 'barelli_professional',
#         'musicianlocation_room', '45classes_are_scheduled',
#         'following_dates:3/12', 'following_dates:3/14',
#         'yardclasses_are_scheduled', 'room_9classes', '5/22_classes',
#         '41classes', 'teacherlocation', '5classes',
#         '35classes_are_scheduled'],
#        dtype='<U431'),
#  array(['shasta_ski', 'anderson_river', 'k-8_at_mcclellan',
#         'nascent_jefferson', 'octavia_glassell', 'johns_island',
#         'grove_bowl', 'going_to_an_amusement', 'ride_lots',
#         'hopedale_at_town', 'tennis_c/champlin', 'mr._ewan', 'soo_zee',
#         'wyalusing_state', 'bladensburg_waterfront', 'buttonwood'],
#        dtype='<U431'),
#  array(['read_more…', 'uniform_appointments', 'digital_textbook',
#         'save_on_the_scoresheet', 'visit_the_a.s.d', 'keynews_resources',
#         'request_more_infomation', 'scoresheet_tab',
#         'apply_//nyccharterschools.schoolmint.net',
#         '//login.jupitered.com/login/', 'summertime_is_almost',
#         'muncie_applicants', '/viewform_usp=sf', 'fox5_vegas',
#         'onedrive_icon', '//goo.gl/forms/kqukxle2m75e3gb52', 'full…'],
#        dtype='<U431'),
#  array(['vc_pixel', 'fontawesome', 'fontawesome=', 'fa-adjust',
#         'openiconic=', 'vc-oi', 'vc-oi-dial', 'typicons=', 'typcn',
#         'typcn-adjust-brightness', 'entypo=', 'entypo-icon',
#         'entypo-icon-note', 'linecons=', 'li-heart', '2faccount', '2flogon',
#         '252fhomeaccess', '252f|title', '20access|target', 'block=',
#         'pixelicons=', 'icon-alert'],
#        dtype='<U431'),
#  array(['/vc_row', 'row_inner', 'img_size=', 'target=_self', 'image_image=',
#         'column_width=', 'grey_img', 'link_large=', 'inner_vc', '1/1″_vc',
#         'column_inner', 'inner_/vc', '4200″', '4009″_alignment=',
#         'full_link=', 'full_alignment=', 'alignment=_center',
#         'onclick=_link', 'link=_/vc', 'width=_1/3″', '//vols.pt/v4wyed'],
#        dtype='<U431'),
#  array(['dac_committee', 'ecc_committee', 'epc_committee', 'jpc_committee',
#         'lrp_committee', 'seac_council', 'sit_committee', 'spc_committee',
#         'reports_hearings', 'notices_2012-13', 'notices_2011-12',
#         'quaker_electronic', 'bgadoury', 'montessori-rocks'],
#        dtype='<U431'),
#  array(['thes-pta', 'newamer', 'abcd14047', 'phxca', 'doggys',
#         'auggiedoggy', 'cabo456', 'coconutcrew', 'thesrocks', 'redbear',
#         'upbigboy4008', '3puppies', 'ccassell'],
#        dtype='<U431'),
#  array(['breyon_chappell', 'assists_steals', 'game_notables',
#         'steals_assists', 'taylor_ardoin', 'steal_assists', 'd._chavis',
#         'a._prevost', 'dyamond_chavis', 'blocks_steals', 'dyamon_chavis',
#         'assists_steal'],
#        dtype='<U431'),
#  array(['bldg_conference', 'cheerleading_clinics', 'seminole_therapy',
#         'x2210', 'ms._jmh', 'mr._herold', 'x2219', 'eba', 'ms._roeper',
#         'x2104', 'x2212', '\u200bconference'],
#        dtype='<U431'),
#  array(['clarinet_saxophone', 'baritone_saxophone', 'oboe_bassoon',
#         'clarinet_trumpet', 'trombone_trumpet', 'viola_violin',
#         'clarinet_flute', 'tuba_and_percussion', 'drums_guitar',
#         'cello_string', 'woodwinds_flute', 'brass_trumpet',
#         'trombone_euphonium', 'oboe_flute', 'percussion_and_xylophone',
#         'trombone_or_percussion', 'flute_oboe', 'trumpet_saxophone',
#         'clarinet_violin', 'euphonium_tuba', 'clarinet_bass'],
#        dtype='<U431'),
#  array(['greathearts_annual', 'wasc_vc', 'ryss_annual', 'bullying_sprigeo',
#         'attendance/absences', 'non-disc', 'newsletters_roadrunner',
#         'ot/pt_caseload', 'aer_status', 'nasl_fy17', '2015\xad-2016_annual',
#         'swwf_audit', 'nast', 'jlcs_audit', 'r2i2_update', 'lapb_financial',
#         'rency', '\u200bannual', 'fy17-3rd_qtr', '5-5-17_superintendent',
#         '3-31-17_superintendent', '9-16-2016_superintendent',
#         '9-9-16_superintendent', '9-23-2016_superintendent',
#         '2-10-17_superintendent', '2-17-17_superintendent',
#         '12-16-16_superintendent', '12-9-16_superintendent',
#         '12-23-16_superintendent', '1-20-17_superintendent',
#         '1-13-17_superintendent', '12-2-16_superintendent',
#         '4-21-17_superintendent', '4-14-17_superintendent',
#         '2-24-17_superintendent', '3-24-17_superintendent',
#         '10-21-16_superintendent', '10-14-16_superintendent',
#         '10-7-16_superintendent', '4-7-17_superintendent', 'preparers',
#         'ocas_transparency', 'ccountability', 'grds'],
#        dtype='<U431'),
#  array(['11-12-2013', '5-5-14', 'glpa_monday', '5-19-2014', '10-7-13',
#         '5-27-2014', '12-9-2013', '12-16-2013', '3-10-14', '4-28-2014'],
#        dtype='<U431'),
#  array(['precious_story', 'mariano_story', 'trinity_story', 'prince_story',
#         'hillary_story', 'ruth_story', 'cecilia_story', 'immanuel_story',
#         'samson_story', 'paola_story', 'jasmine_story', 'lexia_story',
#         'stacey_story', 'sophia_story', 'muriel_story', 'latisha_story',
#         'tenni_story', 'shawn_story', 'full_articl', 'naturally_encore',
#         'anna_mari', 'jua', 'full_article…', 'ignaci', 'paol', 'hilla',
#         'myr', 'samanth'],
#        dtype='<U431'),
#  array(['christopher_chaus', 'jared_harmon', 'kyle_hunter', 'makhani_faiza',
#         'brett_cragun', 'chpt', 'columbus_and_the_pilgrims', 'phil_hohl',
#         'blake_gaudet', 'mary_bringhurst', 'pete_kinnaman', 'crudup',
#         'mr._gelsi', 'kidsmart_english', '10:40-11:40', 'marti_prekker',
#         'mr._lass', 'david_bjorklund', '–katy_warrick', '6-1_6-2',
#         'victoria_apodaca-fisk', 'germaine_harley', 'mharris'],
#        dtype='<U431'),
#  array(['cde_lawsuit', 'elizabeth_wallace', 'mahonri_stewart', 'caleb_hart',
#         'ernst_heather', 'stop_the_flu', 'keep_your_germs',
#         'moreno_berenice', 'slavin_john', 'lopez_maria', 'holler_brett',
#         'seeger_martha', 'blinkinsop_jenna', 'schwartz_robert',
#         'bolton_lisa', 'kruger_maryl', 'kumu_noelani', 'mrs._unruh',
#         'e-funds_manual', 'f_rslp', 'stephon_walker', 'elena_luaces-dryer',
#         'cierra_dornfeld', 'yr._long', 'iv_a/b', 'k-2_sra', 'ii_a/b',
# ...
#        dtype='<U431'),
#  array(['jordin', 'colley', 'schulman', 'magid', 'kanner', 'laureen',
#         'langlois', 'lexy', 'ryman', 'yennaco', 'pember',
#         'kazanjian-silvia', 'caroline_beasley', 'ricard',
#         'barbara_seeber-wagner', 'alice_jane', 'daniella_gutierrez',
#         'mcnierney', 'hannah_macdonald', 'mary_timmons', 'demarines',
#         'm._kretschmar', 'schottler', 'digesse', 'kayvan_kalantar',
#         'mahnke', 'angelina_ebert', 'basma', 'lalli', 'podgorni', 'cadle',
#         'turnbull_patricia', 'basiner', 'scullane', 'wenkai', 'koutsoufis',
#         'selzer'],
#        dtype='<U431'),
#  array(['vaval_dylan', 'annika_parsia', 'tavarez', 'little_gabryela',
#         'caban_sabrina', 'addo_evan', 'eisenberg_daguy',
#         'eisenberg_delilah', 'maximus_jacome', 'christopher_hackett',
#         'little_sabrina', 'addo_gabryela', 'caban_annika', 'parsia_evan',
#         'eisenberg_nicole', 'leonardo_delilah', 'tavarez_jayden',
#         'smith_daguy'],
#        dtype='<U431'),
#  array(['\u200b_5\u200b', '\u200b_7\u200b', '1\u200b_\u200b',
#         '\u200b_6\u200b', '3\u200b_\u200b', '2\u200b_\u200b',
#         '5\u200b_\u200b', '\u200b_4\u200b', '\u200b_2\u200b',
#         '\u200b_8\u200b', '\u200b_3\u200b', '4\u200b_x', '1\u200b_x',
#         '4\u200b_\u200b', '7\u200b', '8\u200b', '6\u200b_\u200b', '6\u200b'],
#        dtype='<U431'),
#  array(['standard_tzoffsetfrom', 'begin_daylight', 'vtimezone_tzid',
#         'dtstart:19870405t020000_rrule', 'freq=yearly_bymonth=4',
#         'byday=1su_until=20061029t020000', 'end_daylight',
#         'dtstart:20070311t020000_rrule', 'freq=yearly_bymonth=3',
#         'byday=2su_end', 'daylight_end', 'vtimezone_begin', 'end_vtimezone',
#         'rrule_freq=yearly', 'begin_vtimezone', 'tzid', '0400_tzoffsetto',
#         'tzoffsetfrom_0500', 'tzoffsetto_0400',
#         'dtstart:20071104t020000_rrule', 'freq=yearly_bymonth=11',
#         'byday=1su_end', '0600', '0500_tzoffsetto',
#         '0500_dtstart:19701025t020000', 'bymonth=10_byday=-1su',
#         'until=20070311t020000_end', 'dtstart:19701025t020000_rrule',
#         'freq=yearly_bymonth=10', 'byday=-1su_until=20070311t020000',
#         '0700_tzoffsetto', '0500_dtstart:20071104t020000',
#         'bymonth=11_byday=1su', 'tzoffsetfrom_0600', 'tzoffsetto_0500',
#         '0600_tzoffsetto', '0700_dtstart:19701025t020000',
#         'tzoffsetfrom_0700', 'tzoffsetto_0600', 'tzoffsetfrom_0800',
#         'tzoffsetto_0700', '0800_tzoffsetto', '0900', 'tzoffsetfrom_0900',
#         'tzoffsetto_0800', '1000_tzoffsetto', '1000_dtstart:19701025t020000'],
#        dtype='<U431'),
#  array(['scroll_smooth', 'blog_installed',
#         'wpb-js-composer_js-comp-ver-5.4.7', ',burst-ver-1.8.1_vertical',
#         'fade_page', 'vertical_menu', 'mkd-core-1.1_ajax',
#         'loaded_,burst-ver-1.8.1', 'page-child_parent-pageid-189',
#         'single-format-standard_mkd-core-1.1', 'page-child_parent-pageid-9',
#         'category_category-spotlights', 'category-129',
#         'page-parent_mkd-core-1.1', 'paged-2', 'paged-3',
#         'parent-pageid-10911', 'parent-pageid-11152'],
#        dtype='<U431'),
#  array(['chicken_tamal', 'carrots_1c', 'chicken_fettuccine', 'beef_2oz',
#         'cheese_.5oz', 'beef_lasagna', 'pilaf_1/2c', '1c_alfredo',
#         'pilaf_1c', '1/2c_alfredo', 'beans_1c', 'pesto_chicken',
#         '3/4c_ranch', 'lemon_pepper', 'sandwich_with_cilantro', 'rice_pilaf'],
#        dtype='<U431'),
#  array(['de_contribuir', 'como_meta', 'internacional_tiene',
#         'formar_jóvenes', 'solidarios_informados', 'ávidos_de',
#         'conocimiento_capaces', 'mundo_mejor', 'marco_del',
#         'entendimiento_mutuo', 'organización_colabora',
#         'con_establecimientos'],
#        dtype='<U431'),
#  array(['2017-05-08_governing', '2017-04-17_governing',
#         '2017-02-13_governing', '2016-11-14_governing',
#         '2016-10-17_governing', '2016-09-19_governing',
#         '2016-08-05_governing', '2016-07-18_governing',
#         '2014-01-10_governing', '2013-11-08_governing',
#         '2013-10-09_governing'],
#        dtype='<U431'),
#  array(['tabia_davis', 'christopher_ortiz', 'scobie_makhi',
#         'godwin_wilson-livingstone', 'ravindra_seupersad', 'jonathan_vega',
#         'victor_augustus', 'kymora_banks', 'adonis_crippen',
#         'baptiste_geordany', 'solomon_makhi'],
#        dtype='<U431'),
#  array(['baltic_times', 'ce_times', 'cyr_times', 'arabid_times',
#         'ce_calibri', 'greek_calibri', 'vietnamese_calibri',
#         'baltic_calibri', 'arial_tur', 'arial_hebrew', 'arial_arabid',
#         'arial_baltic', 'arial_vietnamese', 'normal_default', 's11_srowd'],
#        dtype='<U431'),
#  array(['3ulf_data-offset-key=', 'cdcr8_data-offset-key=',
#         'data-editor=_cdcr8', 'data-offset-key=_2kug1-0-0',
#         'data-offset-key=_41lg2-0-0', 'data-offset-key=_b9ip-0-0',
#         'data-offset-key=_egel-0-0', 'data-offset-key=_23kol-0-0',
#         '4m29c-0-0', 'data-offset-key=_celbt-0-0',
#         'data-offset-key=_iri2-0-0', 'a5l8t-0-0',
#         'data-offset-key=_2n1dv-0-0', '47gl8-0-0',
#         'data-offset-key=_atav5-0-0', 'fmhrt-0-0',
#         'data-offset-key=_a6qg0-0-0', 'data-editor=_1rhh1', '2kug1-0-0',
#         '41lg2-0-0', 'b9ip-0-0', 'egel-0-0', '23kol-0-0',
#         'data-offset-key=_4m29c-0-0', 'data-editor=_b19r1', 'celbt-0-0',
#         'iri2-0-0', '2n1dv-0-0', 'atav5-0-0'],
#        dtype='<U431'),
#  array(['roberts_brewington', 'kitchen_brielle', 'roberts_samantha',
#         'king_aston', 'kitchen_boris', 'mccoy_amira', 'miller_jacob',
#         'bae_brielle', 'roberts_beckett', 'byrne_benjamin',
#         'volovik_steven', 'lopez_noah', 'lee_aston', 'hardaway_gerard',
#         'petrella_lucian'],
#        dtype='<U431'),
#  array(['nei', 'ka_papa', 'nā_haumāna', 'ka_makahiki', 'kēia', 'koʻu',
#         'ʻo_wau', 'makahiki_kula', 'loko', 'wau', 'pū', 'ke_kumu', 'nō',
#         'ke_aʻo', 'koʻu_inoa', 'kekahi', 'ʻo_ia', 'waena', 'ʻekolu',
#         'ua_puka', 'lilo', 'ʻauinalā', 'pōmaikaʻi', 'nui_koʻu', 'aku',
#         'ʻo_kēia', 'ʻehā', 'hauʻoli', 'hoʻokahi', 'pilikanaka', 'nā_keiki',
#         'ka_hiki', 'kēia_makahiki', 'akula', 'kumu_kīnānā', 'papa_3-4',
#         'hoʻomaka', 'ko_kākou', 'e_hōʻike', 'iā', 'wau_i_ka', 'ʻoukou',
#         'mauli_ola', 'ka_pūnana', 'leo_o_hilo', 'kēia_kula', 'pahuhopu',
#         'ʻehiku', 'ʻana_mai', 'nō_hoʻi', 'ʻaneʻi', 'au_ma_ke', 'au_i_ka',
#         'kekahi_o_nā', 'ka_pae', 'kā', 'kaʻu_mau', 'hoʻonaʻauao', 'piha',
#         'pilina', 'pū_au', 'kula_waena', 'pēlā', 'ʻepekema', 'kula_ʻo',
#         'aʻo_ʻana', 'ka_ʻike', 'mākou', 'nui_ka', 'iaʻu', 'kulanui', 'muli',
#         'au_mai', 'maʻi'],
#        dtype='<U431'),
#  array(['vk', 'nx', '=3dfunction', 'a.preventdefault', 'this.db', 'this.qa',
#         'hk', 'vh', 'iw', '=3dg', 'c=3d0', 'a.currentstyle', 'xj', 'this.b',
#         'this.w', 'this.mh', 'this.da', 'oq', 'l=3d', '=3dc',
#         'c=3dmath.max', 'c=3da', 'bn', 'i=', 'c.height', 'vj', 'a=3db',
#         '||null', 'a.shiftkey', 'u.p=3dfunction_a_b', 'b.id', 'a.ha',
#         'a=3dmath.max', 'a.clienty', 'var_a=3dti', 'f.disabled', 'math.abs',
#         '/a.oa_b', 'd.y', 'hk=3d', 'd=3dd', 'h=3d0', '=3dthis.top', 'a.y',
#         'g=3dmath.min', '=3d=3dpv', 'b.x', 'a.width', 'c=3dc',
#         'u.j=3dfunction', 'decodeuricomponent', 'a.pg', '.max', 'this.xh',
#         'this.dg', 'a.qb', 'u.bg=3dfunction', 'this.mc', 'b=3dti', 'b=3dsh',
#         'kq', '.appendchild', 'a.ea', 'this.rh', 'u.ia=3dfunction',
#         'u.pa=3dfunction', 'a.od', '=3dmath.abs', 'a=3dthis.sf'],
#        dtype='<U431'),
#  array(['sedation_§endodontics', '§periodontics_§repair',
#         'removable_dentures', '§adjustments_tissue',
#         'conditioning_rebasing', 'relining_of_removable',
#         'dentures_§repair', 're-cementation_of_bridges', '§crowns_inlays',
#         'onlays_§repair', 're-cementation_of_cast', 'crowns/inlays/onlays'],
#        dtype='<U431'),
#  array(['casino_blackjack', '//onlinecasinochase.com/_online',
#         '//onlinecasinoiplay.com/_online', '//onlinecasinoinus.com/_online',
#         'casino_bonus', '//onlinecasinovegas.us.org/_online',
#         '//onlinecasinoslots.us.org/', 'bovada_casino',
#         '//onlinecasinoplay.us.org/', '//onlinecasino24.us.org/',
#         '//onlinecasino777.us.org/_online', 'bonus_/url',
#         '//realmoneycasino.us.org/_online', '//onlinecasinoha.us.org/',
#         '//onlinecasino2018.us.org/_online', 'casinos_for_us',
#         '//onlinecasinoplay24.com/_online',
#         'games_//onlinecasino2018.us.org/',
#         '//casinorealmoney.us.org/_casino', 'blackjack_/url',
#         '//onlinecasino24.us.org/_best',
#         'games_//onlinecasinogames.us.org/',
#         '//onlinecasinoha.us.org/_casino', 'gambling_casino',
#         'games_//onlinecasinoslots.us.org/', 'borgata',
#         'slots_//onlinecasinogames.us.org/',
#         '//onlinecasinogames.us.org/_gsn', '//onlinecasinoqr.com/',
#         'casino_//casinorealmoney.us.org/',
#         'slots_//realmoneycasino.us.org/',
#         'slots_//casinorealmoney.us.org/',
#         'casino_//onlinecasino2018.us.org/'],
#        dtype='<U431'),
#  array(['field_field-name-field-image',
#         'field-type-image_field-label-hidden', 'og_image', 'rdfs_seealso',
#         'resource=', 'img_typeof=', 'alt=_/a', '20logo.png_itok=j4md4avz',
#         'datatype=_news', '20team.jpg', '20logo.png', '20cere',
#         '20sing.jpeg', '20shells.jpeg'],
#        dtype='<U431'),
#  array(['br_text-indent', '.25in_br', 'mso-level-number-format_bullet',
#         'br_mso-level-text', 'mso-level-tab-stop_none',
#         'br_mso-level-number-position', 'br_mso-level-tab-stop',
#         'font-family_wingdings', 'ï\x82§_br', 'br_margin-left:0in',
#         'ï\x82·_br', 'list_l1', 'mso-level-start-at:0_br',
#         'mso-level-text_br', 'br_text-indent:0in', 'level2_br', 'level3_br',
#         'level4_br', 'level5_br', 'level6_br', 'level7_br', 'level8_br',
#         'level9_br', 'mso-level-number-format', 'alpha-lower'],
#        dtype='<U431'),
#  array(['false_/w', 'trackformatting', 'punctuationkerning',
#         'validateagainstschemas', 'donotpromoteqf', 'breakwrappedtables',
#         'snaptogridincell', 'wraptextwithpunct', 'useasianbreakrules',
#         'dontgrowautofit', 'splitpgbreakandparamark',
#         'enableopentypekerning', 'dontflipmirrorindents',
#         'br_saveifxmlinvalid', 'saveifxmlinvalid_br',
#         'ignoremixedcontent_false', '/w_ignoremixedcontent',
#         'br_alwaysshowplaceholdertext', 'alwaysshowplaceholdertext_br',
#         'br_lidthemeother', 'en-us_/w', 'lidthemeother_br', 'lidthemeasian',
#         'x-none_/w', 'lidthemeasian_br', 'lidthemecomplexscript_x-none',
#         '/w_lidthemecomplexscript', 'br_compatibility'],
#        dtype='<U431'),
#  array(['page_wordsection1', '.5in_br', 'style_definitions',
#         'br_size:8.5in', '11.0in_br', 'br_mso-header-margin',
#         'mso-footer-margin_.5in', 'margin:1.0in_1.25in', '1.0in_1.25in',
#         'p.msonormal_li.msonormal', 'div.msonormal_br',
#         'mso-style-unhide_no_br', 'br_margin:0in', 'br_font-size:12.0pt',
#         'auto_mso-margin-bottom-alt', 'br_mso-font-signature:647',
#         'fantasy_span', 'br_auto', 'br_mso-font-charset:78',
#         'widow-orphan_br', 'br_mso-font-pitch',
#         'mso-generic-font-family_auto', 'variable_br', 'cambria_br',
#         'br_mso-style-qformat', 'br_mso-hansi-font-family', 'fantasy_br',
#         'margin-bottom_.0001pt', 'background-image_initial',
#         'background-position_initial', 'mso-pagination_none',
#         'panose-1:2_br', 'br_mso-bidi-theme-font', 'minor-bidi_br',
#         'font-size:10.0pt_br', 'calibri_br', 'mso-font-charset:0_br',
#         'minor-latin_br', 'æ\x98\x8eæ\x9c\x9d_br', '5.4pt_0in',
#         'mso-hansi-theme-font_minor-latin', 'margin-bottom_0.0001pt',
#         '/font_class=', 'heading_char', 'mso-para-margin-bottom_.0001pt',
#         'br_mso-font-signature:1', 'br_mso-ascii-font-family',
#         'br_mso-style-priority:34', 'margin-left_.5in', 'margin-left_0in',
#         'quot_mso-bidi-font-family', 'quot_mso-fareast-font-family',
#         'font-size:12.0pt_br', 'mso-margin-bottom-alt_auto',
#         'margin-top:0in_br', 'margin-right:0in_br',
#         'mso-font-signature_536870145', 'auto_span', 'br_margin-right:0in',
#         'margin-bottom:0in_br', 'mso-add-space_auto', '.25in_mso-list',
#         'l0_level1', 'lfo1_br', 'br_mso-ascii-theme-font', 'margin:0in_br',
#         'font-family_bradley', 'hand_itc', 'tt-bold',
#         'table.msonormaltable_br', 'mso-style-name_table',
#         'mso-tstyle-rowband-size:0_br', 'mso-tstyle-colband-size:0_br',
#         'mso-style-noshow_yes', 'br_mso-padding-alt:0in', '5.4pt_br',
#         'mso-para-margin:0in_br', 'mso-ascii-theme-font_minor-latin',
#         'symbol_â·', 'font-family_ï¼\xadï¼³', 'none_align=',
#         'mso-ascii-font-family_cambria',
#         'mso-fareast-font-family_ï¼\xadï¼³', 'font-size_13.5pt',
#         'auto_margin-bottom', 'br_12.0pt', 'mso-font-charset:78_br',
#         'page-break-after_avoid', 'br_mso-font-charset:128',
#         'br_mso-style-next', '36pt', 'wingdings_br',
#         'style=_margin-bottom:0in', 'br_margin-top:0in',
#         'mso-fareast-theme-font_minor-latin', 'abcprint_br',
#         'sans-serif_margin', 'margin-right:0in', 'br_8.0pt',
#         'margin-left:9.0pt', 'div.section1', 'verdana_br', 'br_panose-1:0',
#         'roman_br', 'mso-font-format_other_br', 'mso-font-pitch_fixed',
#         'mso-fareast-font-family_times', 'verdana_arial',
#         'mso-font-charset:2_br', 'mso-font-signature:0_2147483648',
#         'br_line-height:115', 'mso-ascii-font-family_calibri',
#         'mso-hansi-font-family_calibri', 'bluerevconstruction.com',
#         'style=_margin-top:0in', '.0001pt_text-indent', 'l1_level3',
#         'lfo1_span', 'mso-fareast-font-family_wingdings',
#         'margin-bottom:0in', '.0001pt', 'p.msotitle', 'li.msotitle',
#         'div.msotitle', 'p.msobodytext', 'li.msobodytext',
#         'div.msobodytext', 'br_margin-bottom:10.0pt',
#         'br_mso-hansi-theme-font', 'margin-bottom:10.0pt_br',
#         'mso-font-signature:3_br', 'mso-font-signature:647_br',
#         'br_margin-left', 'br_mso-add-space', 'p.msolistparagraphcxspfirst',
#         'li.msolistparagraphcxspfirst', 'div.msolistparagraphcxspfirst',
#         'p.msolistparagraphcxspmiddle', 'li.msolistparagraphcxspmiddle',
#         'div.msolistparagraphcxspmiddle', 'p.msolistparagraphcxsplast',
#         'li.msolistparagraphcxsplast', 'div.msolistparagraphcxsplast',
#         '1.25in_br', 'mso-header-margin_.5in', 'br_mso-footer-margin',
#         '1.0in', 'style=_mso-pagination', 'none_mso-layout-grid-align'],
#        dtype='<U431'),
#  array(['otro_plantel', '¿qué_mejor', 'todo_acerca', 'nuevas_familias',
#         'hijo_a_no_ha', 'sido_admitido', 'del_usted', 'año_¿cómo',
#         'puedo_transferirme', 'también_podrán', 'estamos_ansiosos',
#         'aquí_pero', 'esencia_de', 'pero_siempre', 'evento_para',
#         'de_aquellos', 'también_pensamos', 'capturar_la', 'escriba_al',
#         'continúe_leyendo', 'él_tiene', 'porque_piensa', 'es_duro',
#         'ofrecerán_tutoría', 'sus_nuevos', 'aceptado_un', 'un_emocionante',
#         'yo_aliento', 'conocen_mejor—', '¡estudiantes_y_personal',
#         'el_conocer', 'es_verdad', 'conocerán_estudiantes', 'les_ayudarán',
#         'darse_una', 'por_verles', 'en_¡bienvenido'],
#        dtype='<U431'),
#  array(['post_navigation', 'constellationschools.com', 'priority=_name=',
#         ..., 'sportives', 'culturel', 'périscolaires'],
#        dtype='<U431'),
#  array(['na_temelju', 'žive_online', 'nastave_resursi', 'za_traženje',
#         'drugih_klasa', 'resursa_koje', 'svijet_ima', 'za_ponuditi',
#         'predivnu_podršku', 'roditeljima_i_studentima', 'volim_mogućnosti',
#         'da_bismo', 'mogli_birati', 'između_vrlo', 'strukturiranih_klasa',
#         'nestrukturiranih_razreda', 'jer_ih', 'možemo_prilagoditi',
#         'jedinstvenih_osobina', 'svakog_djeteta', 'izborni_bi',
#         'izbor_zajedno', 'izborom_knjiga', 'kurikuluma_pojačavao',
#         'moje_interese', 'djeteta'],
#        dtype='<U431'),
#  array(['the', 'school', 'and', ..., 'glazers', 'ckcs/brms', '608-845-2255'],
#        dtype='<U431')]
