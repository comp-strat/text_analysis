# %% [markdown]
# # Install Libraries and Load Data

# %%
library('stm')
library('devtools')
library('tm')
library("Rtsne")
library("rsvd")
library("geometry")
# Out:
# Error in library("stm"): there is no package called ‘stm’
# Traceback:
#
# 1. library("stm")

# %%
load('/home/jovyan/work/swarm/output/stm_select_allvars_image.RData')
load('/home/jovyan/work/text_analysis/topic_modeling/charterSelectBestModel.RData')
load('/home/jovyan/work/text_analysis/topic_modeling/estimateEffectData.RData')

# %%
ls()
# Out:
#  [1] "asian_effect"            "black_effect"
#  [3] "black_hispanic"          "black_hispanic_district"
#  [5] "charterSelect"           "data"
#  [7] "docs"                    "hispanic_effect"
#  [9] "hispblack_district"      "hispblack_effect"
# [11] "meta"                    "model"
# [13] "out"                     "processed"
# [15] "vocab"                   "whasian_district"
# [17] "whasian_effect"          "white_black"
# [19] "white_black_district"    "white_effect"
# [21] "white_hispanic"          "white_hispanic_district"

# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Topic Loess

# %%
plotTopicLoess(model, topics=c(13),covariate= meta$black_students)
# Out:
# Plot with title “”

# %%
plotTopicLoess(model, topics=20),covariate= meta$black_students)

# %% [markdown]
# ## Plot Estimate Effect

# %%
plot(white_black, covariate='black_students', topics=13, model=model, method='pointestimate')
# Out:
# Plot with title “”
